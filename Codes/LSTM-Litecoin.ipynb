# %% [markdown]
# ### **LSTM model on Litecoin Coin price data**

# %%
# import required libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from math import sqrt
import matplotlib.pyplot as plt

# load data
df = pd.read_csv('coin_Litecoin.csv')
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%y %H:%M')
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)
dataset = df['Close'].values.reshape(-1, 1)

# preprocess data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# split data into training and testing sets
train_size = int(len(scaled_data) * 0.7)
train_data = scaled_data[:train_size, :]
test_data = scaled_data[train_size:, :]

# function to create LSTM dataset
def create_dataset(dataset, look_back=1):
    X, y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(y)

# create training and testing data for LSTM model
look_back = 3
X_train, y_train = create_dataset(train_data, look_back)
X_test, y_test = create_dataset(test_data, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# create and train LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)

# make predictions on test data
y_pred = model.predict(X_test)

# inverse transform the scaled data
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred = scaler.inverse_transform(y_pred)


# evaluate model using various performance metrics
print('Evaluation Metrics for {}:'.format(df['Name'][0]))
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
r2 = r2_score(y_test, y_pred)
corr = np.corrcoef(y_pred.T, y_test.T)[0, 1]

print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Error (MAE):', mae)
print('Mean Absolute Percentage Error (MAPE):', mape)
print('R-squared:', r2)
print('Correlation Coefficient:', corr)

# get the name of the currency from the DataFrame
currency_name = df['Name'][0]

# plot actual vs predicted values
plt.figure(figsize=(12,6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('{} Actual vs Predicted Values'.format(currency_name))
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1149/1149 - 4s - loss: 0.0017 - 4s/epoch - 3ms/step
# Epoch 2/100
# 1149/1149 - 2s - loss: 8.2171e-04 - 2s/epoch - 1ms/step
# Epoch 3/100
# 1149/1149 - 2s - loss: 7.3725e-04 - 2s/epoch - 2ms/step
# Epoch 4/100
# 1149/1149 - 2s - loss: 6.7227e-04 - 2s/epoch - 2ms/step
# Epoch 5/100
# 1149/1149 - 2s - loss: 6.7561e-04 - 2s/epoch - 1ms/step
# Epoch 6/100
# 1149/1149 - 2s - loss: 6.5673e-04 - 2s/epoch - 1ms/step
# Epoch 7/100
# 1149/1149 - 2s - loss: 5.9279e-04 - 2s/epoch - 1ms/step
# Epoch 8/100
# 1149/1149 - 2s - loss: 5.2843e-04 - 2s/epoch - 1ms/step
# Epoch 9/100
# 1149/1149 - 2s - loss: 4.7975e-04 - 2s/epoch - 1ms/step
# Epoch 10/100
# 1149/1149 - 2s - loss: 5.0409e-04 - 2s/epoch - 1ms/step
# Epoch 11/100
# 1149/1149 - 1s - loss: 4.9215e-04 - 1s/epoch - 1ms/step
# Epoch 12/100
# 1149/1149 - 2s - loss: 4.8998e-04 - 2s/epoch - 1ms/step
# Epoch 13/100
# 1149/1149 - 2s - loss: 4.5450e-04 - 2s/epoch - 1ms/step
# Epoch 14/100
# 1149/1149 - 2s - loss: 4.8163e-04 - 2s/epoch - 1ms/step
# Epoch 15/100
# 1149/1149 - 2s - loss: 4.5591e-04 - 2s/epoch - 1ms/step
# Epoch 16/100
# 1149/1149 - 2s - loss: 4.7210e-04 - 2s/epoch - 1ms/step
# Epoch 17/100
# 1149/1149 - 2s - loss: 4.5779e-04 - 2s/epoch - 1ms/step
# Epoch 18/100
# 1149/1149 - 2s - loss: 4.1062e-04 - 2s/epoch - 1ms/step
# Epoch 19/100
# 1149/1149 - 2s - loss: 4.5553e-04 - 2s/epoch - 1ms/step
# Epoch 20/100
# 1149/1149 - 2s - loss: 4.4155e-04 - 2s/epoch - 1ms/step
# Epoch 21/100
# 1149/1149 - 2s - loss: 4.5925e-04 - 2s/epoch - 1ms/step
# Epoch 22/100
# 1149/1149 - 2s - loss: 4.1599e-04 - 2s/epoch - 1ms/step
# Epoch 23/100
# 1149/1149 - 2s - loss: 4.1575e-04 - 2s/epoch - 1ms/step
# Epoch 24/100
# 1149/1149 - 2s - loss: 4.4903e-04 - 2s/epoch - 1ms/step
# Epoch 25/100
# 1149/1149 - 2s - loss: 4.2225e-04 - 2s/epoch - 1ms/step
# Epoch 26/100
# 1149/1149 - 2s - loss: 4.1579e-04 - 2s/epoch - 1ms/step
# Epoch 27/100
# 1149/1149 - 2s - loss: 4.2257e-04 - 2s/epoch - 1ms/step
# Epoch 28/100
# 1149/1149 - 1s - loss: 4.1749e-04 - 1s/epoch - 1ms/step
# Epoch 29/100
# 1149/1149 - 2s - loss: 4.1292e-04 - 2s/epoch - 1ms/step
# Epoch 30/100
# 1149/1149 - 2s - loss: 4.2229e-04 - 2s/epoch - 1ms/step
# Epoch 31/100
# 1149/1149 - 2s - loss: 4.1864e-04 - 2s/epoch - 1ms/step
# Epoch 32/100
# 1149/1149 - 2s - loss: 4.4435e-04 - 2s/epoch - 1ms/step
# Epoch 33/100
# 1149/1149 - 2s - loss: 4.1518e-04 - 2s/epoch - 1ms/step
# Epoch 34/100
# 1149/1149 - 2s - loss: 4.1430e-04 - 2s/epoch - 1ms/step
# Epoch 35/100
# 1149/1149 - 2s - loss: 4.0901e-04 - 2s/epoch - 1ms/step
# Epoch 36/100
# 1149/1149 - 2s - loss: 4.0536e-04 - 2s/epoch - 1ms/step
# Epoch 37/100
# 1149/1149 - 1s - loss: 4.1359e-04 - 1s/epoch - 1ms/step
# Epoch 38/100
# 1149/1149 - 2s - loss: 4.1819e-04 - 2s/epoch - 1ms/step
# Epoch 39/100
# 1149/1149 - 1s - loss: 4.2356e-04 - 1s/epoch - 1ms/step
# Epoch 40/100
# 1149/1149 - 2s - loss: 4.0843e-04 - 2s/epoch - 1ms/step
# Epoch 41/100
# 1149/1149 - 1s - loss: 4.0999e-04 - 1s/epoch - 1ms/step
# Epoch 42/100
# 1149/1149 - 2s - loss: 4.0510e-04 - 2s/epoch - 1ms/step
# Epoch 43/100
# 1149/1149 - 2s - loss: 4.3943e-04 - 2s/epoch - 1ms/step
# Epoch 44/100
# 1149/1149 - 2s - loss: 3.9662e-04 - 2s/epoch - 1ms/step
# Epoch 45/100
# 1149/1149 - 2s - loss: 4.0134e-04 - 2s/epoch - 1ms/step
# Epoch 46/100
# 1149/1149 - 2s - loss: 4.1333e-04 - 2s/epoch - 1ms/step
# Epoch 47/100
# 1149/1149 - 2s - loss: 4.2103e-04 - 2s/epoch - 1ms/step
# Epoch 48/100
# 1149/1149 - 2s - loss: 3.9848e-04 - 2s/epoch - 1ms/step
# Epoch 49/100
# 1149/1149 - 2s - loss: 3.8847e-04 - 2s/epoch - 1ms/step
# Epoch 50/100
# 1149/1149 - 2s - loss: 3.9127e-04 - 2s/epoch - 1ms/step
# Epoch 51/100
# 1149/1149 - 2s - loss: 4.0441e-04 - 2s/epoch - 1ms/step
# Epoch 52/100
# 1149/1149 - 2s - loss: 4.0507e-04 - 2s/epoch - 1ms/step
# Epoch 53/100
# 1149/1149 - 2s - loss: 3.8904e-04 - 2s/epoch - 1ms/step
# Epoch 54/100
# 1149/1149 - 2s - loss: 3.9217e-04 - 2s/epoch - 1ms/step
# Epoch 55/100
# 1149/1149 - 2s - loss: 4.1024e-04 - 2s/epoch - 1ms/step
# Epoch 56/100
# 1149/1149 - 2s - loss: 4.0759e-04 - 2s/epoch - 1ms/step
# Epoch 57/100
# 1149/1149 - 1s - loss: 3.8467e-04 - 1s/epoch - 1ms/step
# Epoch 58/100
# 1149/1149 - 2s - loss: 4.0738e-04 - 2s/epoch - 1ms/step
# Epoch 59/100
# 1149/1149 - 2s - loss: 3.8659e-04 - 2s/epoch - 1ms/step
# Epoch 60/100
# 1149/1149 - 2s - loss: 4.1024e-04 - 2s/epoch - 1ms/step
# Epoch 61/100
# 1149/1149 - 2s - loss: 3.7540e-04 - 2s/epoch - 1ms/step
# Epoch 62/100
# 1149/1149 - 2s - loss: 3.8871e-04 - 2s/epoch - 1ms/step
# Epoch 63/100
# 1149/1149 - 1s - loss: 3.8387e-04 - 1s/epoch - 1ms/step
# Epoch 64/100
# 1149/1149 - 2s - loss: 4.0786e-04 - 2s/epoch - 1ms/step
# Epoch 65/100
# 1149/1149 - 1s - loss: 3.8517e-04 - 1s/epoch - 1ms/step
# Epoch 66/100
# 1149/1149 - 2s - loss: 4.0508e-04 - 2s/epoch - 2ms/step
# Epoch 67/100
# 1149/1149 - 2s - loss: 4.0066e-04 - 2s/epoch - 1ms/step
# Epoch 68/100
# 1149/1149 - 2s - loss: 3.8119e-04 - 2s/epoch - 1ms/step
# Epoch 69/100
# 1149/1149 - 2s - loss: 3.8872e-04 - 2s/epoch - 1ms/step
# Epoch 70/100
# 1149/1149 - 2s - loss: 3.8785e-04 - 2s/epoch - 1ms/step
# Epoch 71/100
# 1149/1149 - 2s - loss: 3.9386e-04 - 2s/epoch - 1ms/step
# Epoch 72/100
# 1149/1149 - 2s - loss: 3.8861e-04 - 2s/epoch - 1ms/step
# Epoch 73/100
# 1149/1149 - 2s - loss: 4.0034e-04 - 2s/epoch - 1ms/step
# Epoch 74/100
# 1149/1149 - 2s - loss: 3.8866e-04 - 2s/epoch - 1ms/step
# Epoch 75/100
# 1149/1149 - 2s - loss: 3.7935e-04 - 2s/epoch - 1ms/step
# Epoch 76/100
# 1149/1149 - 2s - loss: 4.0053e-04 - 2s/epoch - 1ms/step
# Epoch 77/100
# 1149/1149 - 2s - loss: 3.8503e-04 - 2s/epoch - 1ms/step
# Epoch 78/100
# 1149/1149 - 2s - loss: 3.9508e-04 - 2s/epoch - 1ms/step
# Epoch 79/100
# 1149/1149 - 2s - loss: 3.8866e-04 - 2s/epoch - 1ms/step
# Epoch 80/100
# 1149/1149 - 2s - loss: 3.8800e-04 - 2s/epoch - 1ms/step
# Epoch 81/100
# 1149/1149 - 2s - loss: 3.9156e-04 - 2s/epoch - 1ms/step
# Epoch 82/100
# 1149/1149 - 2s - loss: 3.8046e-04 - 2s/epoch - 1ms/step
# Epoch 83/100
# 1149/1149 - 2s - loss: 3.8413e-04 - 2s/epoch - 1ms/step
# Epoch 84/100
# 1149/1149 - 2s - loss: 3.8743e-04 - 2s/epoch - 1ms/step
# Epoch 85/100
# 1149/1149 - 2s - loss: 3.7496e-04 - 2s/epoch - 1ms/step
# Epoch 86/100
# 1149/1149 - 2s - loss: 3.8364e-04 - 2s/epoch - 1ms/step
# Epoch 87/100
# 1149/1149 - 2s - loss: 3.7622e-04 - 2s/epoch - 1ms/step
# Epoch 88/100
# 1149/1149 - 2s - loss: 3.6822e-04 - 2s/epoch - 1ms/step
# Epoch 89/100
# 1149/1149 - 2s - loss: 3.8801e-04 - 2s/epoch - 1ms/step
# Epoch 90/100
# 1149/1149 - 2s - loss: 3.9788e-04 - 2s/epoch - 1ms/step
# Epoch 91/100
# 1149/1149 - 2s - loss: 3.7821e-04 - 2s/epoch - 1ms/step
# Epoch 92/100
# 1149/1149 - 2s - loss: 4.0119e-04 - 2s/epoch - 1ms/step
# Epoch 93/100
# 1149/1149 - 2s - loss: 3.6479e-04 - 2s/epoch - 1ms/step
# Epoch 94/100
# 1149/1149 - 2s - loss: 3.9630e-04 - 2s/epoch - 2ms/step
# Epoch 95/100
# 1149/1149 - 2s - loss: 3.7795e-04 - 2s/epoch - 1ms/step
# Epoch 96/100
# 1149/1149 - 2s - loss: 3.9315e-04 - 2s/epoch - 1ms/step
# Epoch 97/100
# 1149/1149 - 2s - loss: 3.8579e-04 - 2s/epoch - 1ms/step
# Epoch 98/100
# 1149/1149 - 2s - loss: 3.9294e-04 - 2s/epoch - 1ms/step
# Epoch 99/100
# 1149/1149 - 2s - loss: 3.8572e-04 - 2s/epoch - 1ms/step
# Epoch 100/100
# 1149/1149 - 2s - loss: 3.8263e-04 - 2s/epoch - 1ms/step
# 16/16 [==============================] - 0s 1ms/step
# Evaluation Metrics for Litecoin:
# Mean Squared Error (MSE): 118.67419617234546
# Root Mean Squared Error (RMSE): 10.893768685461678
# Mean Absolute Error (MAE): 6.43132660031791
# Mean Absolute Percentage Error (MAPE): 5.941765404715629
# R-squared: 0.9810125191872658
# Correlation Coefficient: 0.9917435294579042

# %%
# import required libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from math import sqrt
import matplotlib.pyplot as plt

# load data
df = pd.read_csv('coin_Litecoin.csv')
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%y %H:%M')
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)
dataset = df['Close'].values.reshape(-1, 1)

# preprocess data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# split data into training and testing sets
train_size = int(len(scaled_data) * 0.7)
train_data = scaled_data[:train_size, :]
test_data = scaled_data[train_size:, :]

# function to create LSTM dataset
def create_dataset(dataset, look_back=1):
    X, y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(y)

# create training and testing data for LSTM model
look_back = 3
X_train, y_train = create_dataset(train_data, look_back)
X_test, y_test = create_dataset(test_data, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# create and train LSTM model with dropout
model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 1), dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)

# make predictions on test data
y_pred = model.predict(X_test)

# inverse transform the scaled data
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred = scaler.inverse_transform(y_pred)

# evaluate model using various performance metrics
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
corr = np.corrcoef(y_pred.T, y_test.T)[0, 1]
r2 = r2_score(y_test, y_pred)

# evaluate dropout model using various performance metrics
print('Evaluation Metrics for {} - Dropout Model:'.format(df['Name'][0]))
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Error (MAE):', mae)
print('Mean Absolute Percentage Error (MAPE):', mape)
print('Correlation Coefficient:', corr)
print('R-squared:', r2)

# get the name of the currency from the DataFrame
currency_name = df['Name'][0]

# plot actual vs predicted values
plt.figure(figsize=(12,6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('{} Actual vs Predicted Values - Dropout Model'.format(currency_name))
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1149/1149 - 4s - loss: 0.0067 - 4s/epoch - 3ms/step
# Epoch 2/100
# 1149/1149 - 2s - loss: 0.0049 - 2s/epoch - 2ms/step
# Epoch 3/100
# 1149/1149 - 2s - loss: 0.0044 - 2s/epoch - 2ms/step
# Epoch 4/100
# 1149/1149 - 3s - loss: 0.0042 - 3s/epoch - 3ms/step
# Epoch 5/100
# 1149/1149 - 3s - loss: 0.0037 - 3s/epoch - 3ms/step
# Epoch 6/100
# 1149/1149 - 2s - loss: 0.0033 - 2s/epoch - 2ms/step
# Epoch 7/100
# 1149/1149 - 2s - loss: 0.0029 - 2s/epoch - 2ms/step
# Epoch 8/100
# 1149/1149 - 2s - loss: 0.0027 - 2s/epoch - 2ms/step
# Epoch 9/100
# 1149/1149 - 2s - loss: 0.0025 - 2s/epoch - 2ms/step
# Epoch 10/100
# 1149/1149 - 2s - loss: 0.0023 - 2s/epoch - 2ms/step
# Epoch 11/100
# 1149/1149 - 3s - loss: 0.0024 - 3s/epoch - 3ms/step
# Epoch 12/100
# 1149/1149 - 4s - loss: 0.0024 - 4s/epoch - 3ms/step
# Epoch 13/100
# 1149/1149 - 3s - loss: 0.0022 - 3s/epoch - 3ms/step
# Epoch 14/100
# 1149/1149 - 3s - loss: 0.0021 - 3s/epoch - 2ms/step
# Epoch 15/100
# 1149/1149 - 3s - loss: 0.0021 - 3s/epoch - 2ms/step
# Epoch 16/100
# 1149/1149 - 3s - loss: 0.0021 - 3s/epoch - 2ms/step
# Epoch 17/100
# 1149/1149 - 2s - loss: 0.0023 - 2s/epoch - 2ms/step
# Epoch 18/100
# 1149/1149 - 2s - loss: 0.0020 - 2s/epoch - 2ms/step
# Epoch 19/100
# 1149/1149 - 2s - loss: 0.0020 - 2s/epoch - 2ms/step
# Epoch 20/100
# 1149/1149 - 2s - loss: 0.0020 - 2s/epoch - 2ms/step
# Epoch 21/100
# 1149/1149 - 2s - loss: 0.0020 - 2s/epoch - 2ms/step
# Epoch 22/100
# 1149/1149 - 2s - loss: 0.0016 - 2s/epoch - 2ms/step
# Epoch 23/100
# 1149/1149 - 2s - loss: 0.0017 - 2s/epoch - 2ms/step
# Epoch 24/100
# 1149/1149 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 25/100
# 1149/1149 - 2s - loss: 0.0015 - 2s/epoch - 2ms/step
# Epoch 26/100
# 1149/1149 - 3s - loss: 0.0015 - 3s/epoch - 2ms/step
# Epoch 27/100
# 1149/1149 - 2s - loss: 0.0016 - 2s/epoch - 2ms/step
# Epoch 28/100
# 1149/1149 - 3s - loss: 0.0015 - 3s/epoch - 2ms/step
# Epoch 29/100
# 1149/1149 - 3s - loss: 0.0013 - 3s/epoch - 2ms/step
# Epoch 30/100
# 1149/1149 - 3s - loss: 0.0013 - 3s/epoch - 2ms/step
# Epoch 31/100
# 1149/1149 - 2s - loss: 0.0014 - 2s/epoch - 2ms/step
# Epoch 32/100
# 1149/1149 - 2s - loss: 0.0014 - 2s/epoch - 2ms/step
# Epoch 33/100
# 1149/1149 - 2s - loss: 0.0012 - 2s/epoch - 2ms/step
# Epoch 34/100
# 1149/1149 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 35/100
# 1149/1149 - 2s - loss: 0.0016 - 2s/epoch - 2ms/step
# Epoch 36/100
# 1149/1149 - 2s - loss: 0.0014 - 2s/epoch - 2ms/step
# Epoch 37/100
# 1149/1149 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 38/100
# 1149/1149 - 2s - loss: 0.0012 - 2s/epoch - 2ms/step
# Epoch 39/100
# 1149/1149 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 40/100
# 1149/1149 - 2s - loss: 0.0011 - 2s/epoch - 2ms/step
# Epoch 41/100
# 1149/1149 - 2s - loss: 0.0014 - 2s/epoch - 2ms/step
# Epoch 42/100
# 1149/1149 - 2s - loss: 0.0012 - 2s/epoch - 2ms/step
# Epoch 43/100
# 1149/1149 - 2s - loss: 0.0012 - 2s/epoch - 2ms/step
# Epoch 44/100
# 1149/1149 - 2s - loss: 0.0012 - 2s/epoch - 2ms/step
# Epoch 45/100
# 1149/1149 - 2s - loss: 0.0013 - 2s/epoch - 2ms/step
# Epoch 46/100
# 1149/1149 - 3s - loss: 0.0013 - 3s/epoch - 2ms/step
# Epoch 47/100
# 1149/1149 - 2s - loss: 0.0012 - 2s/epoch - 2ms/step
# Epoch 48/100
# 1149/1149 - 2s - loss: 0.0011 - 2s/epoch - 2ms/step
# Epoch 49/100
# 1149/1149 - 2s - loss: 0.0012 - 2s/epoch - 2ms/step
# Epoch 50/100
# 1149/1149 - 2s - loss: 0.0012 - 2s/epoch - 2ms/step
# Epoch 51/100
# 1149/1149 - 2s - loss: 0.0011 - 2s/epoch - 2ms/step
# Epoch 52/100
# 1149/1149 - 2s - loss: 0.0010 - 2s/epoch - 2ms/step
# Epoch 53/100
# 1149/1149 - 3s - loss: 0.0012 - 3s/epoch - 2ms/step
# Epoch 54/100
# 1149/1149 - 2s - loss: 0.0010 - 2s/epoch - 2ms/step
# Epoch 55/100
# 1149/1149 - 2s - loss: 0.0012 - 2s/epoch - 2ms/step
# Epoch 56/100
# 1149/1149 - 2s - loss: 0.0012 - 2s/epoch - 2ms/step
# Epoch 57/100
# 1149/1149 - 2s - loss: 0.0011 - 2s/epoch - 2ms/step
# Epoch 58/100
# 1149/1149 - 3s - loss: 9.8406e-04 - 3s/epoch - 2ms/step
# Epoch 59/100
# 1149/1149 - 2s - loss: 0.0010 - 2s/epoch - 2ms/step
# Epoch 60/100
# 1149/1149 - 2s - loss: 0.0011 - 2s/epoch - 2ms/step
# Epoch 61/100
# 1149/1149 - 2s - loss: 9.3763e-04 - 2s/epoch - 2ms/step
# Epoch 62/100
# 1149/1149 - 2s - loss: 9.2454e-04 - 2s/epoch - 2ms/step
# Epoch 63/100
# 1149/1149 - 2s - loss: 0.0011 - 2s/epoch - 2ms/step
# Epoch 64/100
# 1149/1149 - 2s - loss: 0.0011 - 2s/epoch - 2ms/step
# Epoch 65/100
# 1149/1149 - 3s - loss: 0.0011 - 3s/epoch - 2ms/step
# Epoch 66/100
# 1149/1149 - 2s - loss: 9.9846e-04 - 2s/epoch - 2ms/step
# Epoch 67/100
# 1149/1149 - 2s - loss: 0.0011 - 2s/epoch - 2ms/step
# Epoch 68/100
# 1149/1149 - 2s - loss: 9.8234e-04 - 2s/epoch - 2ms/step
# Epoch 69/100
# 1149/1149 - 2s - loss: 9.8573e-04 - 2s/epoch - 2ms/step
# Epoch 70/100
# 1149/1149 - 2s - loss: 9.8998e-04 - 2s/epoch - 2ms/step
# Epoch 71/100
# 1149/1149 - 2s - loss: 0.0010 - 2s/epoch - 2ms/step
# Epoch 72/100
# 1149/1149 - 2s - loss: 9.4017e-04 - 2s/epoch - 2ms/step
# Epoch 73/100
# 1149/1149 - 2s - loss: 0.0010 - 2s/epoch - 2ms/step
# Epoch 74/100
# 1149/1149 - 2s - loss: 9.1502e-04 - 2s/epoch - 2ms/step
# Epoch 75/100
# 1149/1149 - 2s - loss: 8.4084e-04 - 2s/epoch - 2ms/step
# Epoch 76/100
# 1149/1149 - 2s - loss: 9.8061e-04 - 2s/epoch - 2ms/step
# Epoch 77/100
# 1149/1149 - 2s - loss: 8.8195e-04 - 2s/epoch - 2ms/step
# Epoch 78/100
# 1149/1149 - 2s - loss: 9.0791e-04 - 2s/epoch - 2ms/step
# Epoch 79/100
# 1149/1149 - 2s - loss: 8.8604e-04 - 2s/epoch - 2ms/step
# Epoch 80/100
# 1149/1149 - 2s - loss: 8.6830e-04 - 2s/epoch - 2ms/step
# Epoch 81/100
# 1149/1149 - 3s - loss: 8.7373e-04 - 3s/epoch - 2ms/step
# Epoch 82/100
# 1149/1149 - 2s - loss: 9.2185e-04 - 2s/epoch - 2ms/step
# Epoch 83/100
# 1149/1149 - 2s - loss: 8.6692e-04 - 2s/epoch - 2ms/step
# Epoch 84/100
# 1149/1149 - 2s - loss: 8.4573e-04 - 2s/epoch - 2ms/step
# Epoch 85/100
# 1149/1149 - 2s - loss: 9.3648e-04 - 2s/epoch - 2ms/step
# Epoch 86/100
# 1149/1149 - 2s - loss: 7.9248e-04 - 2s/epoch - 2ms/step
# Epoch 87/100
# 1149/1149 - 2s - loss: 8.2857e-04 - 2s/epoch - 2ms/step
# Epoch 88/100
# 1149/1149 - 2s - loss: 7.5432e-04 - 2s/epoch - 2ms/step
# Epoch 89/100
# 1149/1149 - 2s - loss: 7.4168e-04 - 2s/epoch - 2ms/step
# Epoch 90/100
# 1149/1149 - 2s - loss: 8.9891e-04 - 2s/epoch - 2ms/step
# Epoch 91/100
# 1149/1149 - 2s - loss: 7.9697e-04 - 2s/epoch - 2ms/step
# Epoch 92/100
# 1149/1149 - 2s - loss: 7.7927e-04 - 2s/epoch - 2ms/step
# Epoch 93/100
# 1149/1149 - 2s - loss: 7.8122e-04 - 2s/epoch - 2ms/step
# Epoch 94/100
# 1149/1149 - 2s - loss: 7.7171e-04 - 2s/epoch - 2ms/step
# Epoch 95/100
# 1149/1149 - 2s - loss: 7.8561e-04 - 2s/epoch - 2ms/step
# Epoch 96/100
# 1149/1149 - 2s - loss: 7.3050e-04 - 2s/epoch - 2ms/step
# Epoch 97/100
# 1149/1149 - 2s - loss: 7.7827e-04 - 2s/epoch - 2ms/step
# Epoch 98/100
# 1149/1149 - 2s - loss: 7.3191e-04 - 2s/epoch - 2ms/step
# Epoch 99/100
# 1149/1149 - 2s - loss: 7.7390e-04 - 2s/epoch - 2ms/step
# Epoch 100/100
# 1149/1149 - 2s - loss: 7.5923e-04 - 2s/epoch - 2ms/step
# 16/16 [==============================] - 0s 2ms/step
# Evaluation Metrics for Litecoin - Dropout Model:
# Mean Squared Error (MSE): 675.922732248998
# Root Mean Squared Error (RMSE): 25.998514039248438
# Mean Absolute Error (MAE): 16.62687646577053
# Mean Absolute Percentage Error (MAPE): 10.829905249742868
# Correlation Coefficient: 0.9898092992725283
# R-squared: 0.8918545874047439
