# %% [markdown]
# ### **LSTM model on Binance Coin price data**

# %%
# import required libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from math import sqrt
import matplotlib.pyplot as plt

# load data
df = pd.read_csv('coin_BinanceCoin.csv')
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)
dataset = df['Close'].values.reshape(-1, 1)

# preprocess data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# split data into training and testing sets
train_size = int(len(scaled_data) * 0.7)
train_data = scaled_data[:train_size, :]
test_data = scaled_data[train_size:, :]

# function to create LSTM dataset
def create_dataset(dataset, look_back=1):
    X, y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(y)

# create training and testing data for LSTM model
look_back = 3
X_train, y_train = create_dataset(train_data, look_back)
X_test, y_test = create_dataset(test_data, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# create and train LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)

# make predictions on test data
y_pred = model.predict(X_test)

# inverse transform the scaled data
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred = scaler.inverse_transform(y_pred)

# evaluate model using various performance metrics
print('Evaluation Metrics for {}:'.format(df['Name'][0]))
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
r2 = r2_score(y_test, y_pred)
corr = np.corrcoef(y_pred.T, y_test.T)[0, 1]

print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Error (MAE):', mae)
print('Mean Absolute Percentage Error (MAPE):', mape)
print('R-squared:', r2)
print('Correlation Coefficient:', corr)

# get the name of the currency from the DataFrame
currency_name = df['Name'][0]

# plot actual vs predicted values
plt.figure(figsize=(12,6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('{} Actual vs Predicted Values'.format(currency_name))
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1005/1005 - 3s - loss: 2.0925e-05 - 3s/epoch - 3ms/step
# Epoch 2/100
# 1005/1005 - 1s - loss: 5.6452e-06 - 1s/epoch - 1ms/step
# Epoch 3/100
# 1005/1005 - 2s - loss: 5.7176e-06 - 2s/epoch - 2ms/step
# Epoch 4/100
# 1005/1005 - 2s - loss: 5.4412e-06 - 2s/epoch - 2ms/step
# Epoch 5/100
# 1005/1005 - 2s - loss: 4.9576e-06 - 2s/epoch - 2ms/step
# Epoch 6/100
# 1005/1005 - 2s - loss: 3.8993e-06 - 2s/epoch - 2ms/step
# Epoch 7/100
# 1005/1005 - 1s - loss: 3.6506e-06 - 1s/epoch - 1ms/step
# Epoch 8/100
# 1005/1005 - 1s - loss: 3.6855e-06 - 1s/epoch - 1ms/step
# Epoch 9/100
# 1005/1005 - 1s - loss: 3.3634e-06 - 1s/epoch - 1ms/step
# Epoch 10/100
# 1005/1005 - 2s - loss: 3.6166e-06 - 2s/epoch - 2ms/step
# Epoch 11/100
# 1005/1005 - 1s - loss: 2.9198e-06 - 1s/epoch - 1ms/step
# Epoch 12/100
# 1005/1005 - 1s - loss: 3.2431e-06 - 1s/epoch - 1ms/step
# Epoch 13/100
# 1005/1005 - 1s - loss: 3.0882e-06 - 1s/epoch - 1ms/step
# Epoch 14/100
# 1005/1005 - 1s - loss: 3.6847e-06 - 1s/epoch - 1ms/step
# Epoch 15/100
# 1005/1005 - 1s - loss: 3.3893e-06 - 1s/epoch - 1ms/step
# Epoch 16/100
# 1005/1005 - 1s - loss: 2.9426e-06 - 1s/epoch - 1ms/step
# Epoch 17/100
# 1005/1005 - 1s - loss: 2.9584e-06 - 1s/epoch - 1ms/step
# Epoch 18/100
# 1005/1005 - 1s - loss: 2.7228e-06 - 1s/epoch - 1ms/step
# Epoch 19/100
# 1005/1005 - 1s - loss: 3.1277e-06 - 1s/epoch - 1ms/step
# Epoch 20/100
# 1005/1005 - 1s - loss: 3.0398e-06 - 1s/epoch - 1ms/step
# Epoch 21/100
# 1005/1005 - 1s - loss: 2.8577e-06 - 1s/epoch - 1ms/step
# Epoch 22/100
# 1005/1005 - 1s - loss: 3.2267e-06 - 1s/epoch - 1ms/step
# Epoch 23/100
# 1005/1005 - 1s - loss: 3.0204e-06 - 1s/epoch - 1ms/step
# Epoch 24/100
# 1005/1005 - 2s - loss: 3.2793e-06 - 2s/epoch - 2ms/step
# Epoch 25/100
# 1005/1005 - 1s - loss: 2.8434e-06 - 1s/epoch - 1ms/step
# Epoch 26/100
# 1005/1005 - 1s - loss: 2.9041e-06 - 1s/epoch - 1ms/step
# Epoch 27/100
# 1005/1005 - 1s - loss: 3.2487e-06 - 1s/epoch - 1ms/step
# Epoch 28/100
# 1005/1005 - 1s - loss: 2.7986e-06 - 1s/epoch - 1ms/step
# Epoch 29/100
# 1005/1005 - 1s - loss: 3.2250e-06 - 1s/epoch - 1ms/step
# Epoch 30/100
# 1005/1005 - 1s - loss: 2.6669e-06 - 1s/epoch - 1ms/step
# Epoch 31/100
# 1005/1005 - 1s - loss: 2.9857e-06 - 1s/epoch - 1ms/step
# Epoch 32/100
# 1005/1005 - 1s - loss: 2.6185e-06 - 1s/epoch - 1ms/step
# Epoch 33/100
# 1005/1005 - 1s - loss: 2.6445e-06 - 1s/epoch - 1ms/step
# Epoch 34/100
# 1005/1005 - 1s - loss: 3.0057e-06 - 1s/epoch - 1ms/step
# Epoch 35/100
# 1005/1005 - 1s - loss: 3.0326e-06 - 1s/epoch - 1ms/step
# Epoch 36/100
# 1005/1005 - 1s - loss: 2.8984e-06 - 1s/epoch - 1ms/step
# Epoch 37/100
# 1005/1005 - 1s - loss: 2.7367e-06 - 1s/epoch - 1ms/step
# Epoch 38/100
# 1005/1005 - 1s - loss: 2.8637e-06 - 1s/epoch - 1ms/step
# Epoch 39/100
# 1005/1005 - 1s - loss: 2.7752e-06 - 1s/epoch - 1ms/step
# Epoch 40/100
# 1005/1005 - 1s - loss: 2.7699e-06 - 1s/epoch - 1ms/step
# Epoch 41/100
# 1005/1005 - 1s - loss: 2.8414e-06 - 1s/epoch - 1ms/step
# Epoch 42/100
# 1005/1005 - 1s - loss: 2.5131e-06 - 1s/epoch - 1ms/step
# Epoch 43/100
# 1005/1005 - 1s - loss: 2.6455e-06 - 1s/epoch - 1ms/step
# Epoch 44/100
# 1005/1005 - 1s - loss: 2.7493e-06 - 1s/epoch - 1ms/step
# Epoch 45/100
# 1005/1005 - 1s - loss: 3.0534e-06 - 1s/epoch - 1ms/step
# Epoch 46/100
# 1005/1005 - 2s - loss: 2.8241e-06 - 2s/epoch - 2ms/step
# Epoch 47/100
# 1005/1005 - 2s - loss: 2.7187e-06 - 2s/epoch - 2ms/step
# Epoch 48/100
# 1005/1005 - 1s - loss: 2.7796e-06 - 1s/epoch - 1ms/step
# Epoch 49/100
# 1005/1005 - 2s - loss: 2.8656e-06 - 2s/epoch - 2ms/step
# Epoch 50/100
# 1005/1005 - 2s - loss: 2.4912e-06 - 2s/epoch - 2ms/step
# Epoch 51/100
# 1005/1005 - 2s - loss: 2.5419e-06 - 2s/epoch - 2ms/step
# Epoch 52/100
# 1005/1005 - 1s - loss: 2.7779e-06 - 1s/epoch - 1ms/step
# Epoch 53/100
# 1005/1005 - 2s - loss: 2.8873e-06 - 2s/epoch - 2ms/step
# Epoch 54/100
# 1005/1005 - 1s - loss: 2.5335e-06 - 1s/epoch - 1ms/step
# Epoch 55/100
# 1005/1005 - 3s - loss: 2.5535e-06 - 3s/epoch - 3ms/step
# Epoch 56/100
# 1005/1005 - 2s - loss: 2.6455e-06 - 2s/epoch - 2ms/step
# Epoch 57/100
# 1005/1005 - 2s - loss: 2.7267e-06 - 2s/epoch - 2ms/step
# Epoch 58/100
# 1005/1005 - 1s - loss: 2.8290e-06 - 1s/epoch - 1ms/step
# Epoch 59/100
# 1005/1005 - 1s - loss: 2.6736e-06 - 1s/epoch - 1ms/step
# Epoch 60/100
# 1005/1005 - 1s - loss: 2.5306e-06 - 1s/epoch - 1ms/step
# Epoch 61/100
# 1005/1005 - 1s - loss: 2.6969e-06 - 1s/epoch - 1ms/step
# Epoch 62/100
# 1005/1005 - 1s - loss: 2.6850e-06 - 1s/epoch - 1ms/step
# Epoch 63/100
# 1005/1005 - 1s - loss: 2.5087e-06 - 1s/epoch - 1ms/step
# Epoch 64/100
# 1005/1005 - 1s - loss: 2.7219e-06 - 1s/epoch - 1ms/step
# Epoch 65/100
# 1005/1005 - 1s - loss: 2.4852e-06 - 1s/epoch - 1ms/step
# Epoch 66/100
# 1005/1005 - 1s - loss: 2.5839e-06 - 1s/epoch - 1ms/step
# Epoch 67/100
# 1005/1005 - 1s - loss: 2.5201e-06 - 1s/epoch - 1ms/step
# Epoch 68/100
# 1005/1005 - 1s - loss: 2.6741e-06 - 1s/epoch - 1ms/step
# Epoch 69/100
# 1005/1005 - 1s - loss: 2.5470e-06 - 1s/epoch - 1ms/step
# Epoch 70/100
# 1005/1005 - 2s - loss: 2.5487e-06 - 2s/epoch - 2ms/step
# Epoch 71/100
# 1005/1005 - 2s - loss: 2.7492e-06 - 2s/epoch - 2ms/step
# Epoch 72/100
# 1005/1005 - 2s - loss: 2.6119e-06 - 2s/epoch - 2ms/step
# Epoch 73/100
# 1005/1005 - 2s - loss: 2.6381e-06 - 2s/epoch - 2ms/step
# Epoch 74/100
# 1005/1005 - 1s - loss: 2.6770e-06 - 1s/epoch - 1ms/step
# Epoch 75/100
# 1005/1005 - 2s - loss: 2.5067e-06 - 2s/epoch - 2ms/step
# Epoch 76/100
# 1005/1005 - 2s - loss: 2.5026e-06 - 2s/epoch - 2ms/step
# Epoch 77/100
# 1005/1005 - 1s - loss: 2.5286e-06 - 1s/epoch - 1ms/step
# Epoch 78/100
# 1005/1005 - 2s - loss: 2.4669e-06 - 2s/epoch - 1ms/step
# Epoch 79/100
# 1005/1005 - 1s - loss: 2.7977e-06 - 1s/epoch - 1ms/step
# Epoch 80/100
# 1005/1005 - 1s - loss: 2.5454e-06 - 1s/epoch - 1ms/step
# Epoch 81/100
# 1005/1005 - 2s - loss: 2.3614e-06 - 2s/epoch - 2ms/step
# Epoch 82/100
# 1005/1005 - 1s - loss: 2.7458e-06 - 1s/epoch - 1ms/step
# Epoch 83/100
# 1005/1005 - 1s - loss: 2.5638e-06 - 1s/epoch - 1ms/step
# Epoch 84/100
# 1005/1005 - 1s - loss: 2.6256e-06 - 1s/epoch - 1ms/step
# Epoch 85/100
# 1005/1005 - 2s - loss: 2.4448e-06 - 2s/epoch - 2ms/step
# Epoch 86/100
# 1005/1005 - 1s - loss: 2.6219e-06 - 1s/epoch - 1ms/step
# Epoch 87/100
# 1005/1005 - 1s - loss: 2.4656e-06 - 1s/epoch - 1ms/step
# Epoch 88/100
# 1005/1005 - 1s - loss: 2.4309e-06 - 1s/epoch - 1ms/step
# Epoch 89/100
# 1005/1005 - 2s - loss: 2.5246e-06 - 2s/epoch - 2ms/step
# Epoch 90/100
# 1005/1005 - 1s - loss: 2.5704e-06 - 1s/epoch - 1ms/step
# Epoch 91/100
# 1005/1005 - 2s - loss: 2.6684e-06 - 2s/epoch - 2ms/step
# Epoch 92/100
# 1005/1005 - 1s - loss: 2.7684e-06 - 1s/epoch - 1ms/step
# Epoch 93/100
# 1005/1005 - 1s - loss: 2.5795e-06 - 1s/epoch - 1ms/step
# Epoch 94/100
# 1005/1005 - 1s - loss: 2.3958e-06 - 1s/epoch - 1ms/step
# Epoch 95/100
# 1005/1005 - 1s - loss: 2.5162e-06 - 1s/epoch - 1ms/step
# Epoch 96/100
# 1005/1005 - 1s - loss: 2.6149e-06 - 1s/epoch - 1ms/step
# Epoch 97/100
# 1005/1005 - 1s - loss: 2.4865e-06 - 1s/epoch - 1ms/step
# Epoch 98/100
# 1005/1005 - 1s - loss: 2.5039e-06 - 1s/epoch - 1ms/step
# Epoch 99/100
# 1005/1005 - 1s - loss: 2.7093e-06 - 1s/epoch - 1ms/step
# Epoch 100/100
# 1005/1005 - 1s - loss: 2.7677e-06 - 1s/epoch - 1ms/step
# 14/14 [==============================] - 0s 1ms/step
# Currency Name: Binance Coin
# Mean Squared Error (MSE): 949.9060498195756
# Root Mean Squared Error (RMSE): 30.82054590398385
# Mean Absolute Error (MAE): 13.838468544376186
# Mean Absolute Percentage Error (MAPE): 5.2712388963950465
# R-squared: 0.970938060911801
# Correlation Coefficient: 0.9932408286606257

# %%
# import required libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from math import sqrt
import matplotlib.pyplot as plt

# load data
df = pd.read_csv('coin_BinanceCoin.csv')
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)
dataset = df['Close'].values.reshape(-1, 1)

# preprocess data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# split data into training and testing sets
train_size = int(len(scaled_data) * 0.7)
train_data = scaled_data[:train_size, :]
test_data = scaled_data[train_size:, :]

# function to create LSTM dataset
def create_dataset(dataset, look_back=1):
    X, y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(y)

# create training and testing data for LSTM model
look_back = 3
X_train, y_train = create_dataset(train_data, look_back)
X_test, y_test = create_dataset(test_data, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# create and train LSTM model with dropout
model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 1), dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)

# make predictions on test data
y_pred = model.predict(X_test)

# inverse transform the scaled data
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred = scaler.inverse_transform(y_pred)

# evaluate model using various performance metrics
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
corr = np.corrcoef(y_pred.T, y_test.T)[0, 1]
r2 = r2_score(y_test, y_pred)

# evaluate dropout model using various performance metrics
print('Evaluation Metrics for {} - Dropout Model:'.format(df['Name'][0]))
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Error (MAE):', mae)
print('Mean Absolute Percentage Error (MAPE):', mape)
print('Correlation Coefficient:', corr)
print('R-squared:', r2)

# get the name of the currency from the DataFrame
currency_name = df['Name'][0]

# plot actual vs predicted values
plt.figure(figsize=(12,6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('{} Actual vs Predicted Values - Dropout Model'.format(currency_name))
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1005/1005 - 3s - loss: 6.4149e-05 - 3s/epoch - 3ms/step
# Epoch 2/100
# 1005/1005 - 2s - loss: 4.3955e-05 - 2s/epoch - 2ms/step
# Epoch 3/100
# 1005/1005 - 2s - loss: 5.4089e-05 - 2s/epoch - 2ms/step
# Epoch 4/100
# 1005/1005 - 2s - loss: 5.7453e-05 - 2s/epoch - 2ms/step
# Epoch 5/100
# 1005/1005 - 2s - loss: 4.8215e-05 - 2s/epoch - 2ms/step
# Epoch 6/100
# 1005/1005 - 2s - loss: 4.5742e-05 - 2s/epoch - 2ms/step
# Epoch 7/100
# 1005/1005 - 2s - loss: 4.4357e-05 - 2s/epoch - 2ms/step
# Epoch 8/100
# 1005/1005 - 2s - loss: 4.5098e-05 - 2s/epoch - 2ms/step
# Epoch 9/100
# 1005/1005 - 2s - loss: 4.1356e-05 - 2s/epoch - 2ms/step
# Epoch 10/100
# 1005/1005 - 2s - loss: 4.3080e-05 - 2s/epoch - 2ms/step
# Epoch 11/100
# 1005/1005 - 2s - loss: 4.5201e-05 - 2s/epoch - 2ms/step
# Epoch 12/100
# 1005/1005 - 2s - loss: 3.9705e-05 - 2s/epoch - 2ms/step
# Epoch 13/100
# 1005/1005 - 2s - loss: 4.2256e-05 - 2s/epoch - 2ms/step
# Epoch 14/100
# 1005/1005 - 2s - loss: 4.1138e-05 - 2s/epoch - 2ms/step
# Epoch 15/100
# 1005/1005 - 2s - loss: 4.3485e-05 - 2s/epoch - 2ms/step
# Epoch 16/100
# 1005/1005 - 2s - loss: 4.3800e-05 - 2s/epoch - 2ms/step
# Epoch 17/100
# 1005/1005 - 2s - loss: 4.4304e-05 - 2s/epoch - 2ms/step
# Epoch 18/100
# 1005/1005 - 2s - loss: 4.4278e-05 - 2s/epoch - 2ms/step
# Epoch 19/100
# 1005/1005 - 2s - loss: 3.8276e-05 - 2s/epoch - 2ms/step
# Epoch 20/100
# 1005/1005 - 2s - loss: 4.0496e-05 - 2s/epoch - 2ms/step
# Epoch 21/100
# 1005/1005 - 2s - loss: 3.4428e-05 - 2s/epoch - 2ms/step
# Epoch 22/100
# 1005/1005 - 2s - loss: 3.0993e-05 - 2s/epoch - 2ms/step
# Epoch 23/100
# 1005/1005 - 2s - loss: 3.2249e-05 - 2s/epoch - 2ms/step
# Epoch 24/100
# 1005/1005 - 2s - loss: 3.3464e-05 - 2s/epoch - 2ms/step
# Epoch 25/100
# 1005/1005 - 2s - loss: 3.3890e-05 - 2s/epoch - 2ms/step
# Epoch 26/100
# 1005/1005 - 2s - loss: 3.4356e-05 - 2s/epoch - 2ms/step
# Epoch 27/100
# 1005/1005 - 2s - loss: 2.8096e-05 - 2s/epoch - 2ms/step
# Epoch 28/100
# 1005/1005 - 2s - loss: 3.3707e-05 - 2s/epoch - 2ms/step
# Epoch 29/100
# 1005/1005 - 2s - loss: 2.9899e-05 - 2s/epoch - 2ms/step
# Epoch 30/100
# 1005/1005 - 2s - loss: 2.9239e-05 - 2s/epoch - 2ms/step
# Epoch 31/100
# 1005/1005 - 2s - loss: 2.9352e-05 - 2s/epoch - 2ms/step
# Epoch 32/100
# 1005/1005 - 2s - loss: 2.8910e-05 - 2s/epoch - 2ms/step
# Epoch 33/100
# 1005/1005 - 2s - loss: 2.9903e-05 - 2s/epoch - 2ms/step
# Epoch 34/100
# 1005/1005 - 2s - loss: 2.7665e-05 - 2s/epoch - 2ms/step
# Epoch 35/100
# 1005/1005 - 2s - loss: 2.8908e-05 - 2s/epoch - 2ms/step
# Epoch 36/100
# 1005/1005 - 2s - loss: 2.7896e-05 - 2s/epoch - 2ms/step
# Epoch 37/100
# 1005/1005 - 2s - loss: 2.4854e-05 - 2s/epoch - 2ms/step
# Epoch 38/100
# 1005/1005 - 2s - loss: 2.7409e-05 - 2s/epoch - 2ms/step
# Epoch 39/100
# 1005/1005 - 2s - loss: 2.4975e-05 - 2s/epoch - 2ms/step
# Epoch 40/100
# 1005/1005 - 2s - loss: 2.4879e-05 - 2s/epoch - 2ms/step
# Epoch 41/100
# 1005/1005 - 2s - loss: 2.5844e-05 - 2s/epoch - 2ms/step
# Epoch 42/100
# 1005/1005 - 2s - loss: 2.5200e-05 - 2s/epoch - 2ms/step
# Epoch 43/100
# 1005/1005 - 2s - loss: 2.3995e-05 - 2s/epoch - 2ms/step
# Epoch 44/100
# 1005/1005 - 2s - loss: 2.5236e-05 - 2s/epoch - 2ms/step
# Epoch 45/100
# 1005/1005 - 2s - loss: 2.2593e-05 - 2s/epoch - 2ms/step
# Epoch 46/100
# 1005/1005 - 2s - loss: 2.4027e-05 - 2s/epoch - 2ms/step
# Epoch 47/100
# 1005/1005 - 2s - loss: 2.2752e-05 - 2s/epoch - 2ms/step
# Epoch 48/100
# 1005/1005 - 2s - loss: 2.7560e-05 - 2s/epoch - 2ms/step
# Epoch 49/100
# 1005/1005 - 2s - loss: 2.5544e-05 - 2s/epoch - 2ms/step
# Epoch 50/100
# 1005/1005 - 2s - loss: 2.4466e-05 - 2s/epoch - 2ms/step
# Epoch 51/100
# 1005/1005 - 2s - loss: 2.7916e-05 - 2s/epoch - 2ms/step
# Epoch 52/100
# 1005/1005 - 2s - loss: 2.3240e-05 - 2s/epoch - 2ms/step
# Epoch 53/100
# 1005/1005 - 2s - loss: 2.5402e-05 - 2s/epoch - 2ms/step
# Epoch 54/100
# 1005/1005 - 2s - loss: 2.3907e-05 - 2s/epoch - 2ms/step
# Epoch 55/100
# 1005/1005 - 2s - loss: 2.3075e-05 - 2s/epoch - 2ms/step
# Epoch 56/100
# 1005/1005 - 2s - loss: 2.2797e-05 - 2s/epoch - 2ms/step
# Epoch 57/100
# 1005/1005 - 2s - loss: 2.3337e-05 - 2s/epoch - 2ms/step
# Epoch 58/100
# 1005/1005 - 2s - loss: 2.7798e-05 - 2s/epoch - 2ms/step
# Epoch 59/100
# 1005/1005 - 2s - loss: 2.1662e-05 - 2s/epoch - 2ms/step
# Epoch 60/100
# 1005/1005 - 2s - loss: 2.4272e-05 - 2s/epoch - 2ms/step
# Epoch 61/100
# 1005/1005 - 2s - loss: 2.3050e-05 - 2s/epoch - 2ms/step
# Epoch 62/100
# 1005/1005 - 2s - loss: 2.2053e-05 - 2s/epoch - 2ms/step
# Epoch 63/100
# 1005/1005 - 2s - loss: 2.2035e-05 - 2s/epoch - 2ms/step
# Epoch 64/100
# 1005/1005 - 2s - loss: 2.3564e-05 - 2s/epoch - 2ms/step
# Epoch 65/100
# 1005/1005 - 2s - loss: 2.3557e-05 - 2s/epoch - 2ms/step
# Epoch 66/100
# 1005/1005 - 2s - loss: 2.3807e-05 - 2s/epoch - 2ms/step
# Epoch 67/100
# 1005/1005 - 2s - loss: 2.5254e-05 - 2s/epoch - 2ms/step
# Epoch 68/100
# 1005/1005 - 2s - loss: 2.7026e-05 - 2s/epoch - 2ms/step
# Epoch 69/100
# 1005/1005 - 2s - loss: 2.2190e-05 - 2s/epoch - 2ms/step
# Epoch 70/100
# 1005/1005 - 2s - loss: 2.3188e-05 - 2s/epoch - 2ms/step
# Epoch 71/100
# 1005/1005 - 2s - loss: 1.9775e-05 - 2s/epoch - 2ms/step
# Epoch 72/100
# 1005/1005 - 2s - loss: 2.4074e-05 - 2s/epoch - 2ms/step
# Epoch 73/100
# 1005/1005 - 2s - loss: 2.1221e-05 - 2s/epoch - 2ms/step
# Epoch 74/100
# 1005/1005 - 2s - loss: 2.2759e-05 - 2s/epoch - 2ms/step
# Epoch 75/100
# 1005/1005 - 2s - loss: 2.1409e-05 - 2s/epoch - 2ms/step
# Epoch 76/100
# 1005/1005 - 2s - loss: 2.2977e-05 - 2s/epoch - 2ms/step
# Epoch 77/100
# 1005/1005 - 2s - loss: 1.9608e-05 - 2s/epoch - 2ms/step
# Epoch 78/100
# 1005/1005 - 2s - loss: 2.2116e-05 - 2s/epoch - 2ms/step
# Epoch 79/100
# 1005/1005 - 2s - loss: 2.2670e-05 - 2s/epoch - 2ms/step
# Epoch 80/100
# 1005/1005 - 2s - loss: 2.0751e-05 - 2s/epoch - 2ms/step
# Epoch 81/100
# 1005/1005 - 2s - loss: 2.2284e-05 - 2s/epoch - 2ms/step
# Epoch 82/100
# 1005/1005 - 2s - loss: 2.0483e-05 - 2s/epoch - 2ms/step
# Epoch 83/100
# 1005/1005 - 2s - loss: 2.2496e-05 - 2s/epoch - 2ms/step
# Epoch 84/100
# 1005/1005 - 2s - loss: 2.1305e-05 - 2s/epoch - 2ms/step
# Epoch 85/100
# 1005/1005 - 2s - loss: 1.8833e-05 - 2s/epoch - 2ms/step
# Epoch 86/100
# 1005/1005 - 2s - loss: 2.4230e-05 - 2s/epoch - 2ms/step
# Epoch 87/100
# 1005/1005 - 2s - loss: 2.2036e-05 - 2s/epoch - 2ms/step
# Epoch 88/100
# 1005/1005 - 2s - loss: 1.9940e-05 - 2s/epoch - 2ms/step
# Epoch 89/100
# 1005/1005 - 2s - loss: 1.8288e-05 - 2s/epoch - 2ms/step
# Epoch 90/100
# 1005/1005 - 2s - loss: 2.0242e-05 - 2s/epoch - 2ms/step
# Epoch 91/100
# 1005/1005 - 2s - loss: 2.0409e-05 - 2s/epoch - 2ms/step
# Epoch 92/100
# 1005/1005 - 2s - loss: 1.9815e-05 - 2s/epoch - 2ms/step
# Epoch 93/100
# 1005/1005 - 2s - loss: 2.2244e-05 - 2s/epoch - 2ms/step
# Epoch 94/100
# 1005/1005 - 2s - loss: 2.2025e-05 - 2s/epoch - 2ms/step
# Epoch 95/100
# 1005/1005 - 2s - loss: 2.2076e-05 - 2s/epoch - 2ms/step
# Epoch 96/100
# 1005/1005 - 2s - loss: 2.2669e-05 - 2s/epoch - 2ms/step
# Epoch 97/100
# 1005/1005 - 2s - loss: 2.0777e-05 - 2s/epoch - 2ms/step
# Epoch 98/100
# 1005/1005 - 2s - loss: 1.9662e-05 - 2s/epoch - 2ms/step
# Epoch 99/100
# 1005/1005 - 2s - loss: 1.8920e-05 - 2s/epoch - 2ms/step
# Epoch 100/100
# 1005/1005 - 2s - loss: 2.0855e-05 - 2s/epoch - 2ms/step
# 14/14 [==============================] - 0s 1ms/step
# Evaluation Metrics for Binance Coin - Dropout Model:
# Mean Squared Error (MSE): 4911.973903457103
# Root Mean Squared Error (RMSE): 70.08547569544707
# Mean Absolute Error (MAE): 35.95593365005618
# Mean Absolute Percentage Error (MAPE): 15.708139177302396
# Correlation Coefficient: 0.9885746136827513
# R-squared: 0.8497204156008826
