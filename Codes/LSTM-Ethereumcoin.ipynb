# %% [markdown]
# ### **LSTM model on Ethereumcoin Coin price data**

# %%
# import required libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from math import sqrt
import matplotlib.pyplot as plt

# load data
df = pd.read_csv('coin_Ethereum.csv')
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%y %H:%M')
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)
dataset = df['Close'].values.reshape(-1, 1)

# preprocess data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# split data into training and testing sets
train_size = int(len(scaled_data) * 0.7)
train_data = scaled_data[:train_size, :]
test_data = scaled_data[train_size:, :]

# function to create LSTM dataset
def create_dataset(dataset, look_back=1):
    X, y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(y)

# create training and testing data for LSTM model
look_back = 3
X_train, y_train = create_dataset(train_data, look_back)
X_test, y_test = create_dataset(test_data, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# create and train LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)

# make predictions on test data
y_pred = model.predict(X_test)

# inverse transform the scaled data
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred = scaler.inverse_transform(y_pred)


# evaluate model using various performance metrics
print('Evaluation Metrics for {}:'.format(df['Name'][0]))
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
r2 = r2_score(y_test, y_pred)
corr = np.corrcoef(y_pred.T, y_test.T)[0, 1]

print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Error (MAE):', mae)
print('Mean Absolute Percentage Error (MAPE):', mape)
print('R-squared:', r2)
print('Correlation Coefficient:', corr)

# get the name of the currency from the DataFrame
currency_name = df['Name'][0]

# plot actual vs predicted values
plt.figure(figsize=(12,6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('{} Actual vs Predicted Values'.format(currency_name))
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1149/1149 - 4s - loss: 5.1433e-04 - 4s/epoch - 3ms/step
# Epoch 2/100
# 1149/1149 - 2s - loss: 1.0515e-04 - 2s/epoch - 1ms/step
# Epoch 3/100
# 1149/1149 - 2s - loss: 1.0547e-04 - 2s/epoch - 1ms/step
# Epoch 4/100
# 1149/1149 - 2s - loss: 8.3559e-05 - 2s/epoch - 2ms/step
# Epoch 5/100
# 1149/1149 - 2s - loss: 8.0224e-05 - 2s/epoch - 1ms/step
# Epoch 6/100
# 1149/1149 - 2s - loss: 8.0177e-05 - 2s/epoch - 1ms/step
# Epoch 7/100
# 1149/1149 - 2s - loss: 7.1393e-05 - 2s/epoch - 1ms/step
# Epoch 8/100
# 1149/1149 - 2s - loss: 7.6874e-05 - 2s/epoch - 1ms/step
# Epoch 9/100
# 1149/1149 - 2s - loss: 5.6322e-05 - 2s/epoch - 1ms/step
# Epoch 10/100
# 1149/1149 - 2s - loss: 5.5118e-05 - 2s/epoch - 1ms/step
# Epoch 11/100
# 1149/1149 - 2s - loss: 6.1513e-05 - 2s/epoch - 1ms/step
# Epoch 12/100
# 1149/1149 - 2s - loss: 5.7417e-05 - 2s/epoch - 1ms/step
# Epoch 13/100
# 1149/1149 - 2s - loss: 5.2524e-05 - 2s/epoch - 1ms/step
# Epoch 14/100
# 1149/1149 - 2s - loss: 4.7403e-05 - 2s/epoch - 1ms/step
# Epoch 15/100
# 1149/1149 - 2s - loss: 4.8211e-05 - 2s/epoch - 1ms/step
# Epoch 16/100
# 1149/1149 - 2s - loss: 5.7812e-05 - 2s/epoch - 1ms/step
# Epoch 17/100
# 1149/1149 - 2s - loss: 5.2392e-05 - 2s/epoch - 1ms/step
# Epoch 18/100
# 1149/1149 - 2s - loss: 4.2196e-05 - 2s/epoch - 1ms/step
# Epoch 19/100
# 1149/1149 - 2s - loss: 4.6475e-05 - 2s/epoch - 1ms/step
# Epoch 20/100
# 1149/1149 - 2s - loss: 5.0063e-05 - 2s/epoch - 1ms/step
# Epoch 21/100
# 1149/1149 - 2s - loss: 4.6218e-05 - 2s/epoch - 1ms/step
# Epoch 22/100
# 1149/1149 - 2s - loss: 4.9977e-05 - 2s/epoch - 1ms/step
# Epoch 23/100
# 1149/1149 - 2s - loss: 4.7924e-05 - 2s/epoch - 1ms/step
# Epoch 24/100
# 1149/1149 - 2s - loss: 5.0650e-05 - 2s/epoch - 1ms/step
# Epoch 25/100
# 1149/1149 - 2s - loss: 4.4571e-05 - 2s/epoch - 1ms/step
# Epoch 26/100
# 1149/1149 - 2s - loss: 4.6100e-05 - 2s/epoch - 1ms/step
# Epoch 27/100
# 1149/1149 - 2s - loss: 4.6573e-05 - 2s/epoch - 1ms/step
# Epoch 28/100
# 1149/1149 - 2s - loss: 4.3661e-05 - 2s/epoch - 1ms/step
# Epoch 29/100
# 1149/1149 - 2s - loss: 4.6330e-05 - 2s/epoch - 1ms/step
# Epoch 30/100
# 1149/1149 - 2s - loss: 4.4283e-05 - 2s/epoch - 1ms/step
# Epoch 31/100
# 1149/1149 - 2s - loss: 4.5507e-05 - 2s/epoch - 2ms/step
# Epoch 32/100
# 1149/1149 - 2s - loss: 4.4129e-05 - 2s/epoch - 1ms/step
# Epoch 33/100
# 1149/1149 - 2s - loss: 4.7362e-05 - 2s/epoch - 1ms/step
# Epoch 34/100
# 1149/1149 - 2s - loss: 4.5516e-05 - 2s/epoch - 1ms/step
# Epoch 35/100
# 1149/1149 - 2s - loss: 4.6718e-05 - 2s/epoch - 1ms/step
# Epoch 36/100
# 1149/1149 - 2s - loss: 4.4887e-05 - 2s/epoch - 1ms/step
# Epoch 37/100
# 1149/1149 - 2s - loss: 4.4904e-05 - 2s/epoch - 1ms/step
# Epoch 38/100
# 1149/1149 - 2s - loss: 4.7965e-05 - 2s/epoch - 1ms/step
# Epoch 39/100
# 1149/1149 - 2s - loss: 4.2598e-05 - 2s/epoch - 2ms/step
# Epoch 40/100
# 1149/1149 - 2s - loss: 4.7250e-05 - 2s/epoch - 1ms/step
# Epoch 41/100
# 1149/1149 - 2s - loss: 4.1733e-05 - 2s/epoch - 1ms/step
# Epoch 42/100
# 1149/1149 - 2s - loss: 4.1898e-05 - 2s/epoch - 1ms/step
# Epoch 43/100
# 1149/1149 - 2s - loss: 4.5422e-05 - 2s/epoch - 1ms/step
# Epoch 44/100
# 1149/1149 - 2s - loss: 4.4631e-05 - 2s/epoch - 1ms/step
# Epoch 45/100
# 1149/1149 - 2s - loss: 4.4767e-05 - 2s/epoch - 1ms/step
# Epoch 46/100
# 1149/1149 - 2s - loss: 4.3807e-05 - 2s/epoch - 2ms/step
# Epoch 47/100
# 1149/1149 - 2s - loss: 4.3319e-05 - 2s/epoch - 1ms/step
# Epoch 48/100
# 1149/1149 - 2s - loss: 4.2823e-05 - 2s/epoch - 1ms/step
# Epoch 49/100
# 1149/1149 - 2s - loss: 4.3075e-05 - 2s/epoch - 1ms/step
# Epoch 50/100
# 1149/1149 - 2s - loss: 4.0859e-05 - 2s/epoch - 1ms/step
# Epoch 51/100
# 1149/1149 - 2s - loss: 4.3396e-05 - 2s/epoch - 1ms/step
# Epoch 52/100
# 1149/1149 - 2s - loss: 4.1697e-05 - 2s/epoch - 1ms/step
# Epoch 53/100
# 1149/1149 - 2s - loss: 4.3146e-05 - 2s/epoch - 1ms/step
# Epoch 54/100
# 1149/1149 - 2s - loss: 4.3448e-05 - 2s/epoch - 1ms/step
# Epoch 55/100
# 1149/1149 - 2s - loss: 4.1735e-05 - 2s/epoch - 1ms/step
# Epoch 56/100
# 1149/1149 - 2s - loss: 4.2603e-05 - 2s/epoch - 1ms/step
# Epoch 57/100
# 1149/1149 - 2s - loss: 4.0690e-05 - 2s/epoch - 1ms/step
# Epoch 58/100
# 1149/1149 - 2s - loss: 4.2783e-05 - 2s/epoch - 1ms/step
# Epoch 59/100
# 1149/1149 - 2s - loss: 4.1154e-05 - 2s/epoch - 1ms/step
# Epoch 60/100
# 1149/1149 - 2s - loss: 4.2090e-05 - 2s/epoch - 1ms/step
# Epoch 61/100
# 1149/1149 - 2s - loss: 4.5492e-05 - 2s/epoch - 1ms/step
# Epoch 62/100
# 1149/1149 - 2s - loss: 4.1612e-05 - 2s/epoch - 1ms/step
# Epoch 63/100
# 1149/1149 - 2s - loss: 4.3227e-05 - 2s/epoch - 1ms/step
# Epoch 64/100
# 1149/1149 - 2s - loss: 4.1311e-05 - 2s/epoch - 1ms/step
# Epoch 65/100
# 1149/1149 - 2s - loss: 4.3599e-05 - 2s/epoch - 1ms/step
# Epoch 66/100
# 1149/1149 - 2s - loss: 4.1376e-05 - 2s/epoch - 2ms/step
# Epoch 67/100
# 1149/1149 - 2s - loss: 4.3117e-05 - 2s/epoch - 1ms/step
# Epoch 68/100
# 1149/1149 - 2s - loss: 4.1904e-05 - 2s/epoch - 1ms/step
# Epoch 69/100
# 1149/1149 - 2s - loss: 4.4195e-05 - 2s/epoch - 1ms/step
# Epoch 70/100
# 1149/1149 - 2s - loss: 3.9613e-05 - 2s/epoch - 1ms/step
# Epoch 71/100
# 1149/1149 - 2s - loss: 4.1597e-05 - 2s/epoch - 1ms/step
# Epoch 72/100
# 1149/1149 - 2s - loss: 4.1265e-05 - 2s/epoch - 1ms/step
# Epoch 73/100
# 1149/1149 - 2s - loss: 4.4754e-05 - 2s/epoch - 1ms/step
# Epoch 74/100
# 1149/1149 - 2s - loss: 3.8414e-05 - 2s/epoch - 1ms/step
# Epoch 75/100
# 1149/1149 - 2s - loss: 4.1745e-05 - 2s/epoch - 1ms/step
# Epoch 76/100
# 1149/1149 - 2s - loss: 4.1426e-05 - 2s/epoch - 1ms/step
# Epoch 77/100
# 1149/1149 - 2s - loss: 4.2131e-05 - 2s/epoch - 1ms/step
# Epoch 78/100
# 1149/1149 - 2s - loss: 3.8665e-05 - 2s/epoch - 1ms/step
# Epoch 79/100
# 1149/1149 - 2s - loss: 3.9355e-05 - 2s/epoch - 1ms/step
# Epoch 80/100
# 1149/1149 - 2s - loss: 4.2111e-05 - 2s/epoch - 1ms/step
# Epoch 81/100
# 1149/1149 - 2s - loss: 4.3260e-05 - 2s/epoch - 1ms/step
# Epoch 82/100
# 1149/1149 - 2s - loss: 4.1736e-05 - 2s/epoch - 1ms/step
# Epoch 83/100
# 1149/1149 - 2s - loss: 3.9740e-05 - 2s/epoch - 1ms/step
# Epoch 84/100
# 1149/1149 - 2s - loss: 4.1643e-05 - 2s/epoch - 1ms/step
# Epoch 85/100
# 1149/1149 - 2s - loss: 4.0088e-05 - 2s/epoch - 1ms/step
# Epoch 86/100
# 1149/1149 - 2s - loss: 4.2153e-05 - 2s/epoch - 1ms/step
# Epoch 87/100
# 1149/1149 - 2s - loss: 3.9323e-05 - 2s/epoch - 1ms/step
# Epoch 88/100
# 1149/1149 - 2s - loss: 4.2676e-05 - 2s/epoch - 1ms/step
# Epoch 89/100
# 1149/1149 - 2s - loss: 3.7860e-05 - 2s/epoch - 1ms/step
# Epoch 90/100
# 1149/1149 - 2s - loss: 4.2281e-05 - 2s/epoch - 1ms/step
# Epoch 91/100
# 1149/1149 - 2s - loss: 4.0576e-05 - 2s/epoch - 1ms/step
# Epoch 92/100
# 1149/1149 - 2s - loss: 4.0327e-05 - 2s/epoch - 1ms/step
# Epoch 93/100
# 1149/1149 - 2s - loss: 4.0669e-05 - 2s/epoch - 1ms/step
# Epoch 94/100
# 1149/1149 - 2s - loss: 3.9382e-05 - 2s/epoch - 1ms/step
# Epoch 95/100
# 1149/1149 - 2s - loss: 4.0702e-05 - 2s/epoch - 1ms/step
# Epoch 96/100
# 1149/1149 - 2s - loss: 4.1539e-05 - 2s/epoch - 1ms/step
# Epoch 97/100
# 1149/1149 - 2s - loss: 3.9869e-05 - 2s/epoch - 1ms/step
# Epoch 98/100
# 1149/1149 - 2s - loss: 4.1792e-05 - 2s/epoch - 1ms/step
# Epoch 99/100
# 1149/1149 - 2s - loss: 4.2509e-05 - 2s/epoch - 1ms/step
# Epoch 100/100
# 1149/1149 - 2s - loss: 3.9566e-05 - 2s/epoch - 1ms/step
# 16/16 [==============================] - 0s 1ms/step
# Evaluation Metrics for Ethereum:
# Mean Squared Error (MSE): 22376.30739359453
# Root Mean Squared Error (RMSE): 149.58712308749884
# Mean Absolute Error (MAE): 77.60829609546147
# Mean Absolute Percentage Error (MAPE): 5.637091650855075
# R-squared: 0.9753708614033072
# Correlation Coefficient: 0.9942677813857186

# %%
# import required libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from math import sqrt
import matplotlib.pyplot as plt

# load data
df = pd.read_csv('coin_Ethereum.csv')
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%y %H:%M')
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)
dataset = df['Close'].values.reshape(-1, 1)

# preprocess data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# split data into training and testing sets
train_size = int(len(scaled_data) * 0.7)
train_data = scaled_data[:train_size, :]
test_data = scaled_data[train_size:, :]

# function to create LSTM dataset
def create_dataset(dataset, look_back=1):
    X, y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(y)

# create training and testing data for LSTM model
look_back = 3
X_train, y_train = create_dataset(train_data, look_back)
X_test, y_test = create_dataset(test_data, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# create and train LSTM model with dropout
model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 1), dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)

# make predictions on test data
y_pred = model.predict(X_test)

# inverse transform the scaled data
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred = scaler.inverse_transform(y_pred)

# evaluate model using various performance metrics
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
corr = np.corrcoef(y_pred.T, y_test.T)[0, 1]
r2 = r2_score(y_test, y_pred)

# evaluate dropout model using various performance metrics
print('Evaluation Metrics for {} - Dropout Model:'.format(df['Name'][0]))
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Error (MAE):', mae)
print('Mean Absolute Percentage Error (MAPE):', mape)
print('Correlation Coefficient:', corr)
print('R-squared:', r2)

# get the name of the currency from the DataFrame
currency_name = df['Name'][0]

# plot actual vs predicted values
plt.figure(figsize=(12,6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('{} Actual vs Predicted Values - Dropout Model'.format(currency_name))
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1149/1149 - 4s - loss: 0.0011 - 4s/epoch - 4ms/step
# Epoch 2/100
# 1149/1149 - 2s - loss: 6.4217e-04 - 2s/epoch - 2ms/step
# Epoch 3/100
# 1149/1149 - 2s - loss: 5.9861e-04 - 2s/epoch - 2ms/step
# Epoch 4/100
# 1149/1149 - 2s - loss: 6.3597e-04 - 2s/epoch - 2ms/step
# Epoch 5/100
# 1149/1149 - 2s - loss: 6.4359e-04 - 2s/epoch - 2ms/step
# Epoch 6/100
# 1149/1149 - 2s - loss: 5.8604e-04 - 2s/epoch - 2ms/step
# Epoch 7/100
# 1149/1149 - 2s - loss: 6.0955e-04 - 2s/epoch - 2ms/step
# Epoch 8/100
# 1149/1149 - 2s - loss: 4.8324e-04 - 2s/epoch - 2ms/step
# Epoch 9/100
# 1149/1149 - 2s - loss: 5.3115e-04 - 2s/epoch - 2ms/step
# Epoch 10/100
# 1149/1149 - 2s - loss: 5.3945e-04 - 2s/epoch - 2ms/step
# Epoch 11/100
# 1149/1149 - 2s - loss: 4.6874e-04 - 2s/epoch - 2ms/step
# Epoch 12/100
# 1149/1149 - 2s - loss: 4.3515e-04 - 2s/epoch - 2ms/step
# Epoch 13/100
# 1149/1149 - 2s - loss: 4.2923e-04 - 2s/epoch - 2ms/step
# Epoch 14/100
# 1149/1149 - 2s - loss: 3.9762e-04 - 2s/epoch - 2ms/step
# Epoch 15/100
# 1149/1149 - 2s - loss: 3.8779e-04 - 2s/epoch - 2ms/step
# Epoch 16/100
# 1149/1149 - 2s - loss: 3.5937e-04 - 2s/epoch - 2ms/step
# Epoch 17/100
# 1149/1149 - 2s - loss: 3.5479e-04 - 2s/epoch - 2ms/step
# Epoch 18/100
# 1149/1149 - 2s - loss: 3.4776e-04 - 2s/epoch - 2ms/step
# Epoch 19/100
# 1149/1149 - 2s - loss: 3.4490e-04 - 2s/epoch - 2ms/step
# Epoch 20/100
# 1149/1149 - 2s - loss: 3.3522e-04 - 2s/epoch - 2ms/step
# Epoch 21/100
# 1149/1149 - 2s - loss: 2.8158e-04 - 2s/epoch - 2ms/step
# Epoch 22/100
# 1149/1149 - 2s - loss: 3.0511e-04 - 2s/epoch - 2ms/step
# Epoch 23/100
# 1149/1149 - 2s - loss: 2.9730e-04 - 2s/epoch - 2ms/step
# Epoch 24/100
# 1149/1149 - 2s - loss: 2.9481e-04 - 2s/epoch - 2ms/step
# Epoch 25/100
# 1149/1149 - 2s - loss: 2.4729e-04 - 2s/epoch - 2ms/step
# Epoch 26/100
# 1149/1149 - 2s - loss: 2.8864e-04 - 2s/epoch - 2ms/step
# Epoch 27/100
# 1149/1149 - 2s - loss: 2.2553e-04 - 2s/epoch - 2ms/step
# Epoch 28/100
# 1149/1149 - 2s - loss: 2.2740e-04 - 2s/epoch - 2ms/step
# Epoch 29/100
# 1149/1149 - 2s - loss: 2.3345e-04 - 2s/epoch - 2ms/step
# Epoch 30/100
# 1149/1149 - 2s - loss: 1.8018e-04 - 2s/epoch - 2ms/step
# Epoch 31/100
# 1149/1149 - 2s - loss: 1.8384e-04 - 2s/epoch - 2ms/step
# Epoch 32/100
# 1149/1149 - 2s - loss: 2.2376e-04 - 2s/epoch - 2ms/step
# Epoch 33/100
# 1149/1149 - 2s - loss: 2.1870e-04 - 2s/epoch - 2ms/step
# Epoch 34/100
# 1149/1149 - 2s - loss: 1.8492e-04 - 2s/epoch - 2ms/step
# Epoch 35/100
# 1149/1149 - 2s - loss: 1.7094e-04 - 2s/epoch - 2ms/step
# Epoch 36/100
# 1149/1149 - 2s - loss: 1.9615e-04 - 2s/epoch - 2ms/step
# Epoch 37/100
# 1149/1149 - 2s - loss: 1.9478e-04 - 2s/epoch - 2ms/step
# Epoch 38/100
# 1149/1149 - 2s - loss: 1.8086e-04 - 2s/epoch - 2ms/step
# Epoch 39/100
# 1149/1149 - 2s - loss: 1.6813e-04 - 2s/epoch - 2ms/step
# Epoch 40/100
# 1149/1149 - 2s - loss: 1.7220e-04 - 2s/epoch - 2ms/step
# Epoch 41/100
# 1149/1149 - 2s - loss: 1.8193e-04 - 2s/epoch - 2ms/step
# Epoch 42/100
# 1149/1149 - 2s - loss: 1.7336e-04 - 2s/epoch - 2ms/step
# Epoch 43/100
# 1149/1149 - 2s - loss: 1.8321e-04 - 2s/epoch - 2ms/step
# Epoch 44/100
# 1149/1149 - 2s - loss: 1.9563e-04 - 2s/epoch - 2ms/step
# Epoch 45/100
# 1149/1149 - 2s - loss: 1.9471e-04 - 2s/epoch - 2ms/step
# Epoch 46/100
# 1149/1149 - 2s - loss: 1.6188e-04 - 2s/epoch - 2ms/step
# Epoch 47/100
# 1149/1149 - 2s - loss: 1.6236e-04 - 2s/epoch - 2ms/step
# Epoch 48/100
# 1149/1149 - 2s - loss: 2.0737e-04 - 2s/epoch - 2ms/step
# Epoch 49/100
# 1149/1149 - 2s - loss: 1.6468e-04 - 2s/epoch - 2ms/step
# Epoch 50/100
# 1149/1149 - 2s - loss: 1.6692e-04 - 2s/epoch - 2ms/step
# Epoch 51/100
# 1149/1149 - 2s - loss: 1.7898e-04 - 2s/epoch - 2ms/step
# Epoch 52/100
# 1149/1149 - 2s - loss: 1.6958e-04 - 2s/epoch - 2ms/step
# Epoch 53/100
# 1149/1149 - 2s - loss: 1.7214e-04 - 2s/epoch - 2ms/step
# Epoch 54/100
# 1149/1149 - 2s - loss: 1.6031e-04 - 2s/epoch - 2ms/step
# Epoch 55/100
# 1149/1149 - 2s - loss: 1.7894e-04 - 2s/epoch - 2ms/step
# Epoch 56/100
# 1149/1149 - 2s - loss: 1.5532e-04 - 2s/epoch - 2ms/step
# Epoch 57/100
# 1149/1149 - 2s - loss: 1.6048e-04 - 2s/epoch - 2ms/step
# Epoch 58/100
# 1149/1149 - 2s - loss: 1.6617e-04 - 2s/epoch - 2ms/step
# Epoch 59/100
# 1149/1149 - 2s - loss: 1.4924e-04 - 2s/epoch - 2ms/step
# Epoch 60/100
# 1149/1149 - 2s - loss: 1.6827e-04 - 2s/epoch - 2ms/step
# Epoch 61/100
# 1149/1149 - 2s - loss: 1.6639e-04 - 2s/epoch - 2ms/step
# Epoch 62/100
# 1149/1149 - 2s - loss: 1.5709e-04 - 2s/epoch - 2ms/step
# Epoch 63/100
# 1149/1149 - 2s - loss: 1.6447e-04 - 2s/epoch - 2ms/step
# Epoch 64/100
# 1149/1149 - 2s - loss: 1.5049e-04 - 2s/epoch - 2ms/step
# Epoch 65/100
# 1149/1149 - 2s - loss: 1.4753e-04 - 2s/epoch - 2ms/step
# Epoch 66/100
# 1149/1149 - 2s - loss: 1.3949e-04 - 2s/epoch - 2ms/step
# Epoch 67/100
# 1149/1149 - 2s - loss: 1.4601e-04 - 2s/epoch - 2ms/step
# Epoch 68/100
# 1149/1149 - 2s - loss: 1.5017e-04 - 2s/epoch - 2ms/step
# Epoch 69/100
# 1149/1149 - 2s - loss: 1.5481e-04 - 2s/epoch - 2ms/step
# Epoch 70/100
# 1149/1149 - 2s - loss: 1.5540e-04 - 2s/epoch - 2ms/step
# Epoch 71/100
# 1149/1149 - 2s - loss: 1.3905e-04 - 2s/epoch - 2ms/step
# Epoch 72/100
# 1149/1149 - 2s - loss: 1.5126e-04 - 2s/epoch - 2ms/step
# Epoch 73/100
# 1149/1149 - 2s - loss: 1.7745e-04 - 2s/epoch - 2ms/step
# Epoch 74/100
# 1149/1149 - 2s - loss: 1.5444e-04 - 2s/epoch - 2ms/step
# Epoch 75/100
# 1149/1149 - 2s - loss: 1.4435e-04 - 2s/epoch - 2ms/step
# Epoch 76/100
# 1149/1149 - 2s - loss: 1.3760e-04 - 2s/epoch - 2ms/step
# Epoch 77/100
# 1149/1149 - 2s - loss: 1.4629e-04 - 2s/epoch - 2ms/step
# Epoch 78/100
# 1149/1149 - 2s - loss: 1.2614e-04 - 2s/epoch - 2ms/step
# Epoch 79/100
# 1149/1149 - 2s - loss: 1.3797e-04 - 2s/epoch - 2ms/step
# Epoch 80/100
# 1149/1149 - 2s - loss: 1.4739e-04 - 2s/epoch - 2ms/step
# Epoch 81/100
# 1149/1149 - 2s - loss: 1.5147e-04 - 2s/epoch - 2ms/step
# Epoch 82/100
# 1149/1149 - 2s - loss: 1.2880e-04 - 2s/epoch - 2ms/step
# Epoch 83/100
# 1149/1149 - 2s - loss: 1.6367e-04 - 2s/epoch - 2ms/step
# Epoch 84/100
# 1149/1149 - 2s - loss: 1.3244e-04 - 2s/epoch - 2ms/step
# Epoch 85/100
# 1149/1149 - 2s - loss: 1.4993e-04 - 2s/epoch - 2ms/step
# Epoch 86/100
# 1149/1149 - 2s - loss: 1.3254e-04 - 2s/epoch - 2ms/step
# Epoch 87/100
# 1149/1149 - 2s - loss: 1.4046e-04 - 2s/epoch - 2ms/step
# Epoch 88/100
# 1149/1149 - 2s - loss: 1.2668e-04 - 2s/epoch - 2ms/step
# Epoch 89/100
# 1149/1149 - 2s - loss: 1.4301e-04 - 2s/epoch - 2ms/step
# Epoch 90/100
# 1149/1149 - 2s - loss: 1.3201e-04 - 2s/epoch - 2ms/step
# Epoch 91/100
# 1149/1149 - 2s - loss: 1.4050e-04 - 2s/epoch - 2ms/step
# Epoch 92/100
# 1149/1149 - 2s - loss: 1.3278e-04 - 2s/epoch - 2ms/step
# Epoch 93/100
# 1149/1149 - 2s - loss: 1.3069e-04 - 2s/epoch - 2ms/step
# Epoch 94/100
# 1149/1149 - 2s - loss: 1.2988e-04 - 2s/epoch - 2ms/step
# Epoch 95/100
# 1149/1149 - 2s - loss: 1.3730e-04 - 2s/epoch - 2ms/step
# Epoch 96/100
# 1149/1149 - 2s - loss: 1.2635e-04 - 2s/epoch - 2ms/step
# Epoch 97/100
# 1149/1149 - 2s - loss: 1.6420e-04 - 2s/epoch - 2ms/step
# Epoch 98/100
# 1149/1149 - 2s - loss: 1.2121e-04 - 2s/epoch - 2ms/step
# Epoch 99/100
# 1149/1149 - 2s - loss: 1.3896e-04 - 2s/epoch - 2ms/step
# Epoch 100/100
# 1149/1149 - 2s - loss: 1.2287e-04 - 2s/epoch - 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# Evaluation Metrics for Ethereum - Dropout Model:
# Mean Squared Error (MSE): 196512.56406139355
# Root Mean Squared Error (RMSE): 443.2973765559566
# Mean Absolute Error (MAE): 291.2366067308604
# Mean Absolute Percentage Error (MAPE): 27.05108793038555
# Correlation Coefficient: 0.989847949736255
# R-squared: 0.7837026864564333
