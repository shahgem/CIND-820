# %% [markdown]
# ### **LSTM model on Bitcoin Coin price data**

# %%
# import required libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from math import sqrt
import matplotlib.pyplot as plt

# load data
df = pd.read_csv('coin_Bitcoin.csv')
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%y %H:%M')
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)
dataset = df['Close'].values.reshape(-1, 1)

# preprocess data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# split data into training and testing sets
train_size = int(len(scaled_data) * 0.7)
train_data = scaled_data[:train_size, :]
test_data = scaled_data[train_size:, :]

# function to create LSTM dataset
def create_dataset(dataset, look_back=1):
    X, y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(y)

# create training and testing data for LSTM model
look_back = 3
X_train, y_train = create_dataset(train_data, look_back)
X_test, y_test = create_dataset(test_data, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# create and train LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)

# make predictions on test data
y_pred = model.predict(X_test)

# inverse transform the scaled data
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred = scaler.inverse_transform(y_pred)


# evaluate model using various performance metrics
print('Evaluation Metrics for {}:'.format(df['Name'][0]))
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
r2 = r2_score(y_test, y_pred)
corr = np.corrcoef(y_pred.T, y_test.T)[0, 1]

print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Error (MAE):', mae)
print('Mean Absolute Percentage Error (MAPE):', mape)
print('R-squared:', r2)
print('Correlation Coefficient:', corr)

# get the name of the currency from the DataFrame
currency_name = df['Name'][0]

# plot actual vs predicted values
plt.figure(figsize=(12,6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('{} Actual vs Predicted Values'.format(currency_name))
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1149/1149 - 3s - loss: 2.8857e-04 - 3s/epoch - 3ms/step
# Epoch 2/100
# 1149/1149 - 2s - loss: 9.7601e-05 - 2s/epoch - 1ms/step
# Epoch 3/100
# 1149/1149 - 2s - loss: 8.4766e-05 - 2s/epoch - 1ms/step
# Epoch 4/100
# 1149/1149 - 2s - loss: 8.0411e-05 - 2s/epoch - 2ms/step
# Epoch 5/100
# 1149/1149 - 2s - loss: 6.9830e-05 - 2s/epoch - 2ms/step
# Epoch 6/100
# 1149/1149 - 2s - loss: 7.2363e-05 - 2s/epoch - 2ms/step
# Epoch 7/100
# 1149/1149 - 2s - loss: 6.0127e-05 - 2s/epoch - 1ms/step
# Epoch 8/100
# 1149/1149 - 2s - loss: 6.0109e-05 - 2s/epoch - 2ms/step
# Epoch 9/100
# 1149/1149 - 2s - loss: 5.2550e-05 - 2s/epoch - 1ms/step
# Epoch 10/100
# 1149/1149 - 2s - loss: 5.0015e-05 - 2s/epoch - 1ms/step
# Epoch 11/100
# 1149/1149 - 2s - loss: 5.1100e-05 - 2s/epoch - 2ms/step
# Epoch 12/100
# 1149/1149 - 2s - loss: 4.9642e-05 - 2s/epoch - 1ms/step
# Epoch 13/100
# 1149/1149 - 2s - loss: 4.9696e-05 - 2s/epoch - 2ms/step
# Epoch 14/100
# 1149/1149 - 2s - loss: 4.7632e-05 - 2s/epoch - 2ms/step
# Epoch 15/100
# 1149/1149 - 2s - loss: 5.0296e-05 - 2s/epoch - 2ms/step
# Epoch 16/100
# 1149/1149 - 2s - loss: 4.9668e-05 - 2s/epoch - 2ms/step
# Epoch 17/100
# 1149/1149 - 2s - loss: 4.7190e-05 - 2s/epoch - 2ms/step
# Epoch 18/100
# 1149/1149 - 2s - loss: 4.5892e-05 - 2s/epoch - 2ms/step
# Epoch 19/100
# 1149/1149 - 2s - loss: 5.0029e-05 - 2s/epoch - 2ms/step
# Epoch 20/100
# 1149/1149 - 2s - loss: 4.6026e-05 - 2s/epoch - 2ms/step
# Epoch 21/100
# 1149/1149 - 2s - loss: 4.7603e-05 - 2s/epoch - 1ms/step
# Epoch 22/100
# 1149/1149 - 2s - loss: 5.0681e-05 - 2s/epoch - 2ms/step
# Epoch 23/100
# 1149/1149 - 2s - loss: 5.0672e-05 - 2s/epoch - 2ms/step
# Epoch 24/100
# 1149/1149 - 2s - loss: 4.6231e-05 - 2s/epoch - 1ms/step
# Epoch 25/100
# 1149/1149 - 2s - loss: 4.8874e-05 - 2s/epoch - 1ms/step
# Epoch 26/100
# 1149/1149 - 2s - loss: 4.5063e-05 - 2s/epoch - 1ms/step
# Epoch 27/100
# 1149/1149 - 2s - loss: 4.5700e-05 - 2s/epoch - 1ms/step
# Epoch 28/100
# 1149/1149 - 2s - loss: 4.2432e-05 - 2s/epoch - 1ms/step
# Epoch 29/100
# 1149/1149 - 2s - loss: 4.5122e-05 - 2s/epoch - 2ms/step
# Epoch 30/100
# 1149/1149 - 2s - loss: 4.6007e-05 - 2s/epoch - 1ms/step
# Epoch 31/100
# 1149/1149 - 2s - loss: 4.6614e-05 - 2s/epoch - 2ms/step
# Epoch 32/100
# 1149/1149 - 2s - loss: 4.4065e-05 - 2s/epoch - 2ms/step
# Epoch 33/100
# 1149/1149 - 2s - loss: 4.5611e-05 - 2s/epoch - 2ms/step
# Epoch 34/100
# 1149/1149 - 2s - loss: 4.3249e-05 - 2s/epoch - 2ms/step
# Epoch 35/100
# 1149/1149 - 2s - loss: 4.4589e-05 - 2s/epoch - 2ms/step
# Epoch 36/100
# 1149/1149 - 2s - loss: 4.4118e-05 - 2s/epoch - 2ms/step
# Epoch 37/100
# 1149/1149 - 2s - loss: 4.5807e-05 - 2s/epoch - 2ms/step
# Epoch 38/100
# 1149/1149 - 2s - loss: 4.4600e-05 - 2s/epoch - 2ms/step
# Epoch 39/100
# 1149/1149 - 2s - loss: 4.4697e-05 - 2s/epoch - 1ms/step
# Epoch 40/100
# 1149/1149 - 2s - loss: 4.3349e-05 - 2s/epoch - 2ms/step
# Epoch 41/100
# 1149/1149 - 2s - loss: 4.4047e-05 - 2s/epoch - 2ms/step
# Epoch 42/100
# 1149/1149 - 2s - loss: 4.3473e-05 - 2s/epoch - 1ms/step
# Epoch 43/100
# 1149/1149 - 2s - loss: 4.3736e-05 - 2s/epoch - 2ms/step
# Epoch 44/100
# 1149/1149 - 2s - loss: 4.3888e-05 - 2s/epoch - 1ms/step
# Epoch 45/100
# 1149/1149 - 2s - loss: 4.6211e-05 - 2s/epoch - 2ms/step
# Epoch 46/100
# 1149/1149 - 2s - loss: 4.3423e-05 - 2s/epoch - 1ms/step
# Epoch 47/100
# 1149/1149 - 2s - loss: 4.2889e-05 - 2s/epoch - 1ms/step
# Epoch 48/100
# 1149/1149 - 2s - loss: 4.3857e-05 - 2s/epoch - 2ms/step
# Epoch 49/100
# 1149/1149 - 2s - loss: 4.5339e-05 - 2s/epoch - 2ms/step
# Epoch 50/100
# 1149/1149 - 2s - loss: 4.3528e-05 - 2s/epoch - 2ms/step
# Epoch 51/100
# 1149/1149 - 2s - loss: 4.2850e-05 - 2s/epoch - 2ms/step
# Epoch 52/100
# 1149/1149 - 2s - loss: 4.3689e-05 - 2s/epoch - 2ms/step
# Epoch 53/100
# 1149/1149 - 2s - loss: 4.2658e-05 - 2s/epoch - 2ms/step
# Epoch 54/100
# 1149/1149 - 2s - loss: 4.3351e-05 - 2s/epoch - 2ms/step
# Epoch 55/100
# 1149/1149 - 2s - loss: 4.1974e-05 - 2s/epoch - 1ms/step
# Epoch 56/100
# 1149/1149 - 2s - loss: 4.3599e-05 - 2s/epoch - 1ms/step
# Epoch 57/100
# 1149/1149 - 2s - loss: 4.1144e-05 - 2s/epoch - 2ms/step
# Epoch 58/100
# 1149/1149 - 2s - loss: 4.2143e-05 - 2s/epoch - 2ms/step
# Epoch 59/100
# 1149/1149 - 2s - loss: 4.3206e-05 - 2s/epoch - 2ms/step
# Epoch 60/100
# 1149/1149 - 2s - loss: 4.5195e-05 - 2s/epoch - 1ms/step
# Epoch 61/100
# 1149/1149 - 2s - loss: 4.5652e-05 - 2s/epoch - 2ms/step
# Epoch 62/100
# 1149/1149 - 2s - loss: 4.2055e-05 - 2s/epoch - 2ms/step
# Epoch 63/100
# 1149/1149 - 2s - loss: 4.2642e-05 - 2s/epoch - 2ms/step
# Epoch 64/100
# 1149/1149 - 2s - loss: 4.2830e-05 - 2s/epoch - 1ms/step
# Epoch 65/100
# 1149/1149 - 2s - loss: 4.1623e-05 - 2s/epoch - 2ms/step
# Epoch 66/100
# 1149/1149 - 2s - loss: 4.2843e-05 - 2s/epoch - 2ms/step
# Epoch 67/100
# 1149/1149 - 2s - loss: 4.1720e-05 - 2s/epoch - 2ms/step
# Epoch 68/100
# 1149/1149 - 2s - loss: 4.2200e-05 - 2s/epoch - 2ms/step
# Epoch 69/100
# 1149/1149 - 2s - loss: 4.3324e-05 - 2s/epoch - 2ms/step
# Epoch 70/100
# 1149/1149 - 2s - loss: 4.2043e-05 - 2s/epoch - 2ms/step
# Epoch 71/100
# 1149/1149 - 2s - loss: 4.1737e-05 - 2s/epoch - 1ms/step
# Epoch 72/100
# 1149/1149 - 2s - loss: 4.5657e-05 - 2s/epoch - 2ms/step
# Epoch 73/100
# 1149/1149 - 2s - loss: 4.3060e-05 - 2s/epoch - 1ms/step
# Epoch 74/100
# 1149/1149 - 2s - loss: 4.1248e-05 - 2s/epoch - 2ms/step
# Epoch 75/100
# 1149/1149 - 2s - loss: 4.0189e-05 - 2s/epoch - 2ms/step
# Epoch 76/100
# 1149/1149 - 2s - loss: 4.3931e-05 - 2s/epoch - 1ms/step
# Epoch 77/100
# 1149/1149 - 2s - loss: 4.3081e-05 - 2s/epoch - 2ms/step
# Epoch 78/100
# 1149/1149 - 2s - loss: 4.1881e-05 - 2s/epoch - 2ms/step
# Epoch 79/100
# 1149/1149 - 2s - loss: 4.1561e-05 - 2s/epoch - 2ms/step
# Epoch 80/100
# 1149/1149 - 2s - loss: 4.0880e-05 - 2s/epoch - 1ms/step
# Epoch 81/100
# 1149/1149 - 2s - loss: 4.3185e-05 - 2s/epoch - 2ms/step
# Epoch 82/100
# 1149/1149 - 2s - loss: 4.1111e-05 - 2s/epoch - 2ms/step
# Epoch 83/100
# 1149/1149 - 2s - loss: 4.1673e-05 - 2s/epoch - 2ms/step
# Epoch 84/100
# 1149/1149 - 2s - loss: 4.2725e-05 - 2s/epoch - 1ms/step
# Epoch 85/100
# 1149/1149 - 2s - loss: 4.1660e-05 - 2s/epoch - 1ms/step
# Epoch 86/100
# 1149/1149 - 2s - loss: 4.2856e-05 - 2s/epoch - 2ms/step
# Epoch 87/100
# 1149/1149 - 2s - loss: 4.1507e-05 - 2s/epoch - 1ms/step
# Epoch 88/100
# 1149/1149 - 2s - loss: 4.2309e-05 - 2s/epoch - 2ms/step
# Epoch 89/100
# 1149/1149 - 2s - loss: 4.2995e-05 - 2s/epoch - 1ms/step
# Epoch 90/100
# 1149/1149 - 2s - loss: 4.0360e-05 - 2s/epoch - 1ms/step
# Epoch 91/100
# 1149/1149 - 2s - loss: 4.1349e-05 - 2s/epoch - 1ms/step
# Epoch 92/100
# 1149/1149 - 2s - loss: 4.0770e-05 - 2s/epoch - 1ms/step
# Epoch 93/100
# 1149/1149 - 2s - loss: 4.3750e-05 - 2s/epoch - 1ms/step
# Epoch 94/100
# 1149/1149 - 2s - loss: 4.1760e-05 - 2s/epoch - 1ms/step
# Epoch 95/100
# 1149/1149 - 2s - loss: 4.1565e-05 - 2s/epoch - 2ms/step
# Epoch 96/100
# 1149/1149 - 2s - loss: 4.1698e-05 - 2s/epoch - 2ms/step
# Epoch 97/100
# 1149/1149 - 2s - loss: 4.1760e-05 - 2s/epoch - 2ms/step
# Epoch 98/100
# 1149/1149 - 2s - loss: 4.2707e-05 - 2s/epoch - 1ms/step
# Epoch 99/100
# 1149/1149 - 2s - loss: 4.0675e-05 - 2s/epoch - 1ms/step
# Epoch 100/100
# 1149/1149 - 2s - loss: 4.1515e-05 - 2s/epoch - 1ms/step
# 16/16 [==============================] - 0s 2ms/step
# Evaluation Metrics for Bitcoin:
# Mean Squared Error (MSE): 10617859.972387364
# Root Mean Squared Error (RMSE): 3258.5057883004233
# Mean Absolute Error (MAE): 1890.5413903091267
# Mean Absolute Percentage Error (MAPE): 5.228538333566524
# R-squared: 0.9672329030937196
# Correlation Coefficient: 0.9964287373753921

# %%
# import required libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from math import sqrt
import matplotlib.pyplot as plt

# load data
df = pd.read_csv('coin_Bitcoin.csv')
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%y %H:%M')
df.set_index('Date', inplace=True)
df.sort_index(inplace=True)
dataset = df['Close'].values.reshape(-1, 1)

# preprocess data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# split data into training and testing sets
train_size = int(len(scaled_data) * 0.7)
train_data = scaled_data[:train_size, :]
test_data = scaled_data[train_size:, :]

# function to create LSTM dataset
def create_dataset(dataset, look_back=1):
    X, y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(y)

# create training and testing data for LSTM model
look_back = 3
X_train, y_train = create_dataset(train_data, look_back)
X_test, y_test = create_dataset(test_data, look_back)

# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# create and train LSTM model with dropout
model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 1), dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)

# make predictions on test data
y_pred = model.predict(X_test)

# inverse transform the scaled data
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred = scaler.inverse_transform(y_pred)

# evaluate model using various performance metrics
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
corr = np.corrcoef(y_pred.T, y_test.T)[0, 1]
r2 = r2_score(y_test, y_pred)

# evaluate dropout model using various performance metrics
print('Evaluation Metrics for {} - Dropout Model:'.format(df['Name'][0]))
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Error (MAE):', mae)
print('Mean Absolute Percentage Error (MAPE):', mape)
print('Correlation Coefficient:', corr)
print('R-squared:', r2)

# get the name of the currency from the DataFrame
currency_name = df['Name'][0]

# plot actual vs predicted values
plt.figure(figsize=(12,6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('{} Actual vs Predicted Values - Dropout Model'.format(currency_name))
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 1149/1149 - 4s - loss: 0.0012 - 4s/epoch - 3ms/step
# Epoch 2/100
# 1149/1149 - 2s - loss: 7.9136e-04 - 2s/epoch - 2ms/step
# Epoch 3/100
# 1149/1149 - 2s - loss: 9.0292e-04 - 2s/epoch - 2ms/step
# Epoch 4/100
# 1149/1149 - 2s - loss: 7.9199e-04 - 2s/epoch - 2ms/step
# Epoch 5/100
# 1149/1149 - 2s - loss: 8.1591e-04 - 2s/epoch - 2ms/step
# Epoch 6/100
# 1149/1149 - 2s - loss: 6.1238e-04 - 2s/epoch - 2ms/step
# Epoch 7/100
# 1149/1149 - 2s - loss: 6.0995e-04 - 2s/epoch - 2ms/step
# Epoch 8/100
# 1149/1149 - 2s - loss: 5.6465e-04 - 2s/epoch - 2ms/step
# Epoch 9/100
# 1149/1149 - 2s - loss: 5.4871e-04 - 2s/epoch - 2ms/step
# Epoch 10/100
# 1149/1149 - 2s - loss: 4.8241e-04 - 2s/epoch - 2ms/step
# Epoch 11/100
# 1149/1149 - 2s - loss: 4.3373e-04 - 2s/epoch - 2ms/step
# Epoch 12/100
# 1149/1149 - 2s - loss: 4.2983e-04 - 2s/epoch - 2ms/step
# Epoch 13/100
# 1149/1149 - 2s - loss: 3.5237e-04 - 2s/epoch - 2ms/step
# Epoch 14/100
# 1149/1149 - 2s - loss: 4.0687e-04 - 2s/epoch - 2ms/step
# Epoch 15/100
# 1149/1149 - 2s - loss: 3.8602e-04 - 2s/epoch - 2ms/step
# Epoch 16/100
# 1149/1149 - 2s - loss: 4.0444e-04 - 2s/epoch - 2ms/step
# Epoch 17/100
# 1149/1149 - 2s - loss: 3.5849e-04 - 2s/epoch - 2ms/step
# Epoch 18/100
# 1149/1149 - 2s - loss: 3.3110e-04 - 2s/epoch - 2ms/step
# Epoch 19/100
# 1149/1149 - 2s - loss: 3.4040e-04 - 2s/epoch - 2ms/step
# Epoch 20/100
# 1149/1149 - 2s - loss: 2.9926e-04 - 2s/epoch - 2ms/step
# Epoch 21/100
# 1149/1149 - 2s - loss: 2.8503e-04 - 2s/epoch - 2ms/step
# Epoch 22/100
# 1149/1149 - 2s - loss: 2.4588e-04 - 2s/epoch - 2ms/step
# Epoch 23/100
# 1149/1149 - 2s - loss: 2.5516e-04 - 2s/epoch - 2ms/step
# Epoch 24/100
# 1149/1149 - 2s - loss: 2.0707e-04 - 2s/epoch - 2ms/step
# Epoch 25/100
# 1149/1149 - 2s - loss: 2.2419e-04 - 2s/epoch - 2ms/step
# Epoch 26/100
# 1149/1149 - 2s - loss: 2.0151e-04 - 2s/epoch - 2ms/step
# Epoch 27/100
# 1149/1149 - 2s - loss: 2.0480e-04 - 2s/epoch - 2ms/step
# Epoch 28/100
# 1149/1149 - 2s - loss: 2.3237e-04 - 2s/epoch - 2ms/step
# Epoch 29/100
# 1149/1149 - 2s - loss: 2.2369e-04 - 2s/epoch - 2ms/step
# Epoch 30/100
# 1149/1149 - 2s - loss: 1.7939e-04 - 2s/epoch - 2ms/step
# Epoch 31/100
# 1149/1149 - 2s - loss: 2.0925e-04 - 2s/epoch - 2ms/step
# Epoch 32/100
# 1149/1149 - 2s - loss: 1.9643e-04 - 2s/epoch - 2ms/step
# Epoch 33/100
# 1149/1149 - 2s - loss: 2.0435e-04 - 2s/epoch - 2ms/step
# Epoch 34/100
# 1149/1149 - 2s - loss: 1.6573e-04 - 2s/epoch - 2ms/step
# Epoch 35/100
# 1149/1149 - 2s - loss: 2.0008e-04 - 2s/epoch - 2ms/step
# Epoch 36/100
# 1149/1149 - 2s - loss: 1.8983e-04 - 2s/epoch - 2ms/step
# Epoch 37/100
# 1149/1149 - 2s - loss: 1.6399e-04 - 2s/epoch - 2ms/step
# Epoch 38/100
# 1149/1149 - 2s - loss: 1.7398e-04 - 2s/epoch - 2ms/step
# Epoch 39/100
# 1149/1149 - 2s - loss: 1.7928e-04 - 2s/epoch - 2ms/step
# Epoch 40/100
# 1149/1149 - 2s - loss: 1.7291e-04 - 2s/epoch - 2ms/step
# Epoch 41/100
# 1149/1149 - 2s - loss: 1.7282e-04 - 2s/epoch - 2ms/step
# Epoch 42/100
# 1149/1149 - 2s - loss: 1.6971e-04 - 2s/epoch - 2ms/step
# Epoch 43/100
# 1149/1149 - 2s - loss: 2.0388e-04 - 2s/epoch - 2ms/step
# Epoch 44/100
# 1149/1149 - 2s - loss: 1.7721e-04 - 2s/epoch - 2ms/step
# Epoch 45/100
# 1149/1149 - 2s - loss: 1.9138e-04 - 2s/epoch - 2ms/step
# Epoch 46/100
# 1149/1149 - 2s - loss: 1.5647e-04 - 2s/epoch - 2ms/step
# Epoch 47/100
# 1149/1149 - 2s - loss: 2.0892e-04 - 2s/epoch - 2ms/step
# Epoch 48/100
# 1149/1149 - 2s - loss: 1.6703e-04 - 2s/epoch - 2ms/step
# Epoch 49/100
# 1149/1149 - 2s - loss: 1.5455e-04 - 2s/epoch - 2ms/step
# Epoch 50/100
# 1149/1149 - 2s - loss: 1.6224e-04 - 2s/epoch - 2ms/step
# Epoch 51/100
# 1149/1149 - 2s - loss: 1.7449e-04 - 2s/epoch - 2ms/step
# Epoch 52/100
# 1149/1149 - 2s - loss: 1.6167e-04 - 2s/epoch - 2ms/step
# Epoch 53/100
# 1149/1149 - 2s - loss: 1.5178e-04 - 2s/epoch - 2ms/step
# Epoch 54/100
# 1149/1149 - 3s - loss: 1.5877e-04 - 3s/epoch - 2ms/step
# Epoch 55/100
# 1149/1149 - 2s - loss: 1.6750e-04 - 2s/epoch - 2ms/step
# Epoch 56/100
# 1149/1149 - 2s - loss: 1.5321e-04 - 2s/epoch - 2ms/step
# Epoch 57/100
# 1149/1149 - 2s - loss: 1.5306e-04 - 2s/epoch - 2ms/step
# Epoch 58/100
# 1149/1149 - 2s - loss: 1.6954e-04 - 2s/epoch - 2ms/step
# Epoch 59/100
# 1149/1149 - 2s - loss: 1.4679e-04 - 2s/epoch - 2ms/step
# Epoch 60/100
# 1149/1149 - 2s - loss: 1.7129e-04 - 2s/epoch - 2ms/step
# Epoch 61/100
# 1149/1149 - 3s - loss: 1.6578e-04 - 3s/epoch - 2ms/step
# Epoch 62/100
# 1149/1149 - 3s - loss: 1.5410e-04 - 3s/epoch - 2ms/step
# Epoch 63/100
# 1149/1149 - 2s - loss: 1.5829e-04 - 2s/epoch - 2ms/step
# Epoch 64/100
# 1149/1149 - 3s - loss: 1.6330e-04 - 3s/epoch - 3ms/step
# Epoch 65/100
# 1149/1149 - 2s - loss: 1.4723e-04 - 2s/epoch - 2ms/step
# Epoch 66/100
# 1149/1149 - 2s - loss: 1.4935e-04 - 2s/epoch - 2ms/step
# Epoch 67/100
# 1149/1149 - 2s - loss: 1.6734e-04 - 2s/epoch - 2ms/step
# Epoch 68/100
# 1149/1149 - 2s - loss: 1.3858e-04 - 2s/epoch - 2ms/step
# Epoch 69/100
# 1149/1149 - 2s - loss: 1.3989e-04 - 2s/epoch - 2ms/step
# Epoch 70/100
# 1149/1149 - 2s - loss: 1.5380e-04 - 2s/epoch - 2ms/step
# Epoch 71/100
# 1149/1149 - 2s - loss: 1.4585e-04 - 2s/epoch - 2ms/step
# Epoch 72/100
# 1149/1149 - 2s - loss: 1.5885e-04 - 2s/epoch - 2ms/step
# Epoch 73/100
# 1149/1149 - 2s - loss: 1.4444e-04 - 2s/epoch - 2ms/step
# Epoch 74/100
# 1149/1149 - 2s - loss: 1.3367e-04 - 2s/epoch - 2ms/step
# Epoch 75/100
# 1149/1149 - 2s - loss: 1.2826e-04 - 2s/epoch - 2ms/step
# Epoch 76/100
# 1149/1149 - 2s - loss: 1.4615e-04 - 2s/epoch - 2ms/step
# Epoch 77/100
# 1149/1149 - 2s - loss: 1.6086e-04 - 2s/epoch - 2ms/step
# Epoch 78/100
# 1149/1149 - 2s - loss: 1.4785e-04 - 2s/epoch - 2ms/step
# Epoch 79/100
# 1149/1149 - 2s - loss: 1.4330e-04 - 2s/epoch - 2ms/step
# Epoch 80/100
# 1149/1149 - 2s - loss: 1.7918e-04 - 2s/epoch - 2ms/step
# Epoch 81/100
# 1149/1149 - 2s - loss: 1.4365e-04 - 2s/epoch - 2ms/step
# Epoch 82/100
# 1149/1149 - 2s - loss: 1.2595e-04 - 2s/epoch - 2ms/step
# Epoch 83/100
# 1149/1149 - 2s - loss: 1.2056e-04 - 2s/epoch - 2ms/step
# Epoch 84/100
# 1149/1149 - 2s - loss: 1.3644e-04 - 2s/epoch - 2ms/step
# Epoch 85/100
# 1149/1149 - 2s - loss: 1.3710e-04 - 2s/epoch - 2ms/step
# Epoch 86/100
# 1149/1149 - 2s - loss: 1.4257e-04 - 2s/epoch - 2ms/step
# Epoch 87/100
# 1149/1149 - 2s - loss: 1.3846e-04 - 2s/epoch - 2ms/step
# Epoch 88/100
# 1149/1149 - 2s - loss: 1.4199e-04 - 2s/epoch - 2ms/step
# Epoch 89/100
# 1149/1149 - 2s - loss: 1.2567e-04 - 2s/epoch - 2ms/step
# Epoch 90/100
# 1149/1149 - 2s - loss: 1.2437e-04 - 2s/epoch - 2ms/step
# Epoch 91/100
# 1149/1149 - 2s - loss: 1.4747e-04 - 2s/epoch - 2ms/step
# Epoch 92/100
# 1149/1149 - 2s - loss: 1.2158e-04 - 2s/epoch - 2ms/step
# Epoch 93/100
# 1149/1149 - 2s - loss: 1.3615e-04 - 2s/epoch - 2ms/step
# Epoch 94/100
# 1149/1149 - 2s - loss: 1.3566e-04 - 2s/epoch - 2ms/step
# Epoch 95/100
# 1149/1149 - 2s - loss: 1.4269e-04 - 2s/epoch - 2ms/step
# Epoch 96/100
# 1149/1149 - 2s - loss: 1.6141e-04 - 2s/epoch - 2ms/step
# Epoch 97/100
# 1149/1149 - 2s - loss: 1.3577e-04 - 2s/epoch - 2ms/step
# Epoch 98/100
# 1149/1149 - 2s - loss: 1.5626e-04 - 2s/epoch - 2ms/step
# Epoch 99/100
# 1149/1149 - 2s - loss: 1.3026e-04 - 2s/epoch - 2ms/step
# Epoch 100/100
# 1149/1149 - 2s - loss: 1.3334e-04 - 2s/epoch - 2ms/step
# 16/16 [==============================] - 0s 1ms/step
# Evaluation Metrics for Bitcoin - Dropout Model:
# Mean Squared Error (MSE): 107103887.04883347
# Root Mean Squared Error (RMSE): 10349.100784552902
# Mean Absolute Error (MAE): 7210.410887188963
# Mean Absolute Percentage Error (MAPE): 23.132416069046506
# Correlation Coefficient: 0.9945209291606029
# R-squared: 0.6694735610475986
