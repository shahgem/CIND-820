# %% [markdown]
# ### **LSTM model on Binance Coin price data**

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from tensorflow.keras.utils import plot_model

import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import seaborn as sns

# Load the dataset
data = pd.read_csv('coin_BinanceCoin.csv')

# Filter for Binance Coin data only
bnb = data[data['Name']=='Binance Coin'].copy()

# Split data into training and test sets
bnb_train = bnb[bnb['Date']<'2020-01-01'].copy()
bnb_test = bnb[bnb['Date']>='2020-01-01'].copy()

# Filter for Open, Close, High, Low, and Volume columns for the training 
training_bnb = bnb_train[['Open', 'Close', 'High', 'Low', 'Volume']].copy()

# Normalize the training set
scaler = MinMaxScaler()
training_bnb = scaler.fit_transform(training_bnb)

# Create input and output sequences for the LSTM model
X_train = []
Y_train = []
for i in range(60, len(training_bnb)):
  X_train.append(training_bnb[i-60:i])
  Y_train.append(training_bnb[i,0])
X_train, Y_train = np.array(X_train), np.array(Y_train)

# Define the LSTM model
model = Sequential()
model.add(LSTM(units = 50, return_sequences=True, input_shape = (X_train.shape[1], 5)))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50))
model.add(Dense(units = 1))
model.summary()
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Train the LSTM model
model.fit(X_train, Y_train, epochs = 30, batch_size =50)

# Create input and output sequences for testing the model
past = bnb_train.tail(60)
past_bnb_df = past.append(bnb_test, ignore_index=True)
testing_bnb = past_bnb_df[['Open', 'Close', 'High', 'Low', 'Volume']].copy()
testing_bnb = scaler.transform(testing_bnb)
X_test = []
Y_test = []
for i in range(60, len(testing_bnb)):
  X_test.append(testing_bnb[i-60:i])
  Y_test.append(testing_bnb[i,0])
X_test, Y_test = np.array(X_test), np.array(Y_test)

# Make predictions using the LSTM model
Y_pred = model.predict(X_test)

# Rescale the predicted and actual prices
scale = 1/scaler.scale_[0]
Y_test = Y_test*scale
Y_pred = Y_pred*scale

# Plot the predicted and actual prices
plt.figure(figsize=(20,10))
plt.plot(Y_test, color = 'red', label = 'Real Binance Coin Price')
plt.plot(Y_pred, color = 'green', label = 'Predicted Binance Coin Price')
plt.title('Binance Price Prediction using RNN-LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# Calculate metrics
mse = np.mean((Y_pred - Y_test)**2)
mae = np.mean(np.abs(Y_pred - Y_test))
rmse = np.sqrt(mse)
r2 = 1 - np.sum((Y_test - Y_pred)**2) / np.sum((Y_test - np.mean(Y_test))**2)

# Print metrics
print("Mean Squared Error (MSE): ", mse)
print("Mean Absolute Error (MAE): ", mae)
print("Root Mean Squared Error (RMSE): ", rmse)
print("R-squared (R2): ", r2)

# Calculate correlation between predicted and actual prices
corr = np.corrcoef(Y_pred.reshape(-1), Y_test.reshape(-1))[0][1]

# Print correlation
print("Correlation: ", corr)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_35 (LSTM)              (None, 60, 50)            11200
#
#  dropout_28 (Dropout)        (None, 60, 50)            0
#
#  lstm_36 (LSTM)              (None, 60, 50)            20200
#
#  dropout_29 (Dropout)        (None, 60, 50)            0
#
#  lstm_37 (LSTM)              (None, 60, 50)            20200
#
#  dropout_30 (Dropout)        (None, 60, 50)            0
#
#  lstm_38 (LSTM)              (None, 60, 50)            20200
#
#  dropout_31 (Dropout)        (None, 60, 50)            0
#
#  lstm_39 (LSTM)              (None, 50)                20200
#
#  dense_7 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 92,051
# Trainable params: 92,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 17/17 [==============================] - 10s 151ms/step - loss: 0.0373
# Epoch 2/30
# 17/17 [==============================] - 3s 155ms/step - loss: 0.0093
# Epoch 3/30
# 17/17 [==============================] - 3s 154ms/step - loss: 0.0057
# Epoch 4/30
# 17/17 [==============================] - 3s 154ms/step - loss: 0.0053
# Epoch 5/30
# 17/17 [==============================] - 3s 153ms/step - loss: 0.0050
# Epoch 6/30
# 17/17 [==============================] - 3s 158ms/step - loss: 0.0049
# Epoch 7/30
# 17/17 [==============================] - 3s 156ms/step - loss: 0.0045
# Epoch 8/30
# 17/17 [==============================] - 3s 154ms/step - loss: 0.0048
# Epoch 9/30
# 17/17 [==============================] - 3s 158ms/step - loss: 0.0042
# Epoch 10/30
# 17/17 [==============================] - 3s 153ms/step - loss: 0.0042
# Epoch 11/30
# 17/17 [==============================] - 3s 156ms/step - loss: 0.0043
# Epoch 12/30
# 17/17 [==============================] - 3s 158ms/step - loss: 0.0039
# Epoch 13/30
# 17/17 [==============================] - 3s 153ms/step - loss: 0.0039
# Epoch 14/30
# 17/17 [==============================] - 3s 153ms/step - loss: 0.0036
# Epoch 15/30
# 17/17 [==============================] - 3s 156ms/step - loss: 0.0036
# Epoch 16/30
# 17/17 [==============================] - 3s 157ms/step - loss: 0.0037
# Epoch 17/30
# 17/17 [==============================] - 3s 157ms/step - loss: 0.0031
# Epoch 18/30
# 17/17 [==============================] - 3s 156ms/step - loss: 0.0029
# Epoch 19/30
# 17/17 [==============================] - 3s 155ms/step - loss: 0.0030
# Epoch 20/30
# 17/17 [==============================] - 3s 157ms/step - loss: 0.0027
# Epoch 21/30
# 17/17 [==============================] - 3s 162ms/step - loss: 0.0030
# Epoch 22/30
# 17/17 [==============================] - 3s 155ms/step - loss: 0.0026
# Epoch 23/30
# 17/17 [==============================] - 3s 158ms/step - loss: 0.0030
# Epoch 24/30
# 17/17 [==============================] - 3s 156ms/step - loss: 0.0031
# Epoch 25/30
# 17/17 [==============================] - 3s 156ms/step - loss: 0.0025
# Epoch 26/30
# 17/17 [==============================] - 3s 157ms/step - loss: 0.0024
# Epoch 27/30
# 17/17 [==============================] - 3s 160ms/step - loss: 0.0022
# Epoch 28/30
# 17/17 [==============================] - 3s 159ms/step - loss: 0.0022
# Epoch 29/30
# 17/17 [==============================] - 3s 158ms/step - loss: 0.0021
# Epoch 30/30
# 17/17 [==============================] - 3s 155ms/step - loss: 0.0026
# C:\Users\sahmed\AppData\Local\Temp\ipykernel_4644\3337628157.py:63: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   past_bnb_df = past.append(bnb_test, ignore_index=True)
# 18/18 [==============================] - 2s 40ms/step
# Mean Squared Error (MSE):  34758.6785794633
# Mean Absolute Error (MAE):  99.98116719002606
# Root Mean Squared Error (RMSE):  186.43679513299756
# R-squared (R2):  -682.7213196043009
# Correlation:  0.8289305628191737

# %% [markdown]
# ### **LSTM model on Bitcoin Coin price data**

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from tensorflow.keras.utils import plot_model

import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import seaborn as sns

# Load the dataset
data = pd.read_csv('coin_Bitcoin.csv')

# Filter for Binance Coin data only
btc = data[data['Name']=='Bitcoin'].copy()

# Split data into training and test sets
btc_train = btc[btc['Date']<'2020-01-01'].copy()
btc_test = btc[btc['Date']>='2020-01-01'].copy()

# Filter for Open, Close, High, Low, and Volume columns for the training 
training_btc = btc_train[['Open', 'Close', 'High', 'Low', 'Volume']].copy()

# Normalize the training set
scaler = MinMaxScaler()
training_btc = scaler.fit_transform(training_btc)

# Create input and output sequences for the LSTM model
X_train = []
Y_train = []
for i in range(60, len(training_btc)):
  X_train.append(training_btc[i-60:i])
  Y_train.append(training_btc[i,0])
X_train, Y_train = np.array(X_train), np.array(Y_train)

# Define the LSTM model
model = Sequential()
model.add(LSTM(units = 50, return_sequences=True, input_shape = (X_train.shape[1], 5)))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50))
model.add(Dense(units = 1))
model.summary()
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Train the LSTM model
model.fit(X_train, Y_train, epochs = 30, batch_size =50)

# Create input and output sequences for testing the model
past = btc_train.tail(60)
past_btc_df = past.append(btc_test, ignore_index=True)
testing_btc = past_btc_df[['Open', 'Close', 'High', 'Low', 'Volume']].copy()
testing_btc = scaler.transform(testing_btc)
X_test = []
Y_test = []
for i in range(60, len(testing_btc)):
  X_test.append(testing_btc[i-60:i])
  Y_test.append(testing_btc[i,0])
X_test, Y_test = np.array(X_test), np.array(Y_test)

# Make predictions using the LSTM model
Y_pred = model.predict(X_test)

# Rescale the predicted and actual prices
scale = 1/scaler.scale_[0]
Y_test = Y_test*scale
Y_pred = Y_pred*scale

# Plot the predicted and actual prices
plt.figure(figsize=(20,10))
plt.plot(Y_test, color = 'red', label = 'Actual Bitcoin Price')
plt.plot(Y_pred, color = 'green', label = 'Predicted BitCoin Price')
plt.title('Bitcoim Price Prediction using RNN-LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# Calculate metrics
mse = np.mean((Y_pred - Y_test)**2)
mae = np.mean(np.abs(Y_pred - Y_test))
rmse = np.sqrt(mse)
r2 = 1 - np.sum((Y_test - Y_pred)**2) / np.sum((Y_test - np.mean(Y_test))**2)

# Print metrics
print("Mean Squared Error (MSE): ", mse)
print("Mean Absolute Error (MAE): ", mae)
print("Root Mean Squared Error (RMSE): ", rmse)
print("R-squared (R2): ", r2)

# Calculate correlation between predicted and actual prices
corr = np.corrcoef(Y_pred.reshape(-1), Y_test.reshape(-1))[0][1]

# Print correlation
print("Correlation: ", corr)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_45 (LSTM)              (None, 60, 50)            11200
#
#  dropout_36 (Dropout)        (None, 60, 50)            0
#
#  lstm_46 (LSTM)              (None, 60, 50)            20200
#
#  dropout_37 (Dropout)        (None, 60, 50)            0
#
#  lstm_47 (LSTM)              (None, 60, 50)            20200
#
#  dropout_38 (Dropout)        (None, 60, 50)            0
#
#  lstm_48 (LSTM)              (None, 60, 50)            20200
#
#  dropout_39 (Dropout)        (None, 60, 50)            0
#
#  lstm_49 (LSTM)              (None, 50)                20200
#
#  dense_9 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 92,051
# Trainable params: 92,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 13/13 [==============================] - 10s 142ms/step - loss: 0.0370
# Epoch 2/30
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0150
# Epoch 3/30
# 13/13 [==============================] - 2s 148ms/step - loss: 0.0041
# Epoch 4/30
# 13/13 [==============================] - 2s 145ms/step - loss: 0.0039
# Epoch 5/30
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0035
# Epoch 6/30
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0033
# Epoch 7/30
# 13/13 [==============================] - 2s 150ms/step - loss: 0.0028
# Epoch 8/30
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0026
# Epoch 9/30
# 13/13 [==============================] - 2s 145ms/step - loss: 0.0025
# Epoch 10/30
# 13/13 [==============================] - 2s 144ms/step - loss: 0.0024
# Epoch 11/30
# 13/13 [==============================] - 2s 146ms/step - loss: 0.0033
# Epoch 12/30
# 13/13 [==============================] - 2s 146ms/step - loss: 0.0027
# Epoch 13/30
# 13/13 [==============================] - 2s 146ms/step - loss: 0.0024
# Epoch 14/30
# 13/13 [==============================] - 2s 147ms/step - loss: 0.0027
# Epoch 15/30
# 13/13 [==============================] - 2s 145ms/step - loss: 0.0025
# Epoch 16/30
# 13/13 [==============================] - 2s 150ms/step - loss: 0.0027
# Epoch 17/30
# 13/13 [==============================] - 2s 146ms/step - loss: 0.0025
# Epoch 18/30
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0026
# Epoch 19/30
# 13/13 [==============================] - 2s 144ms/step - loss: 0.0026
# Epoch 20/30
# 13/13 [==============================] - 2s 147ms/step - loss: 0.0023
# Epoch 21/30
# 13/13 [==============================] - 2s 145ms/step - loss: 0.0046
# Epoch 22/30
# 13/13 [==============================] - 2s 147ms/step - loss: 0.0025
# Epoch 23/30
# 13/13 [==============================] - 2s 144ms/step - loss: 0.0020
# Epoch 24/30
# 13/13 [==============================] - 2s 148ms/step - loss: 0.0018
# Epoch 25/30
# 13/13 [==============================] - 2s 156ms/step - loss: 0.0016
# Epoch 26/30
# 13/13 [==============================] - 2s 163ms/step - loss: 0.0013
# Epoch 27/30
# 13/13 [==============================] - 2s 146ms/step - loss: 0.0015
# Epoch 28/30
# 13/13 [==============================] - 2s 145ms/step - loss: 0.0014
# Epoch 29/30
# 13/13 [==============================] - 2s 147ms/step - loss: 0.0012
# Epoch 30/30
# 13/13 [==============================] - 2s 144ms/step - loss: 0.0015
# C:\Users\sahmed\AppData\Local\Temp\ipykernel_4644\402116137.py:63: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   past_btc_df = past.append(btc_test, ignore_index=True)
# 31/31 [==============================] - 3s 41ms/step
# Mean Squared Error (MSE):  420628932.1136723
# Mean Absolute Error (MAE):  12398.385409539458
# Root Mean Squared Error (RMSE):  20509.240164220428
# R-squared (R2):  -1932.3234799523395
# Correlation:  0.9251661721421793

# %% [markdown]
# ### **LSTM model on Cardano Coin price data**

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from tensorflow.keras.utils import plot_model

import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import seaborn as sns

# Load the dataset
data = pd.read_csv('coin_Cardano.csv')

# Filter for Binance Coin data only
ada = data[data['Name']=='Cardano'].copy()

# Split data into training and test sets
ada_train = ada[ada['Date']<'2020-01-01'].copy()
ada_test = ada[ada['Date']>='2020-01-01'].copy()

# Filter for Open, Close, High, Low, and Volume columns for the training 
training_ada = ada_train[['Open', 'Close', 'High', 'Low', 'Volume']].copy()

# Normalize the training set
scaler = MinMaxScaler()
training_ada = scaler.fit_transform(training_ada)

# Create input and output sequences for the LSTM model
X_train = []
Y_train = []
for i in range(60, len(training_ada)):
  X_train.append(training_ada[i-60:i])
  Y_train.append(training_ada[i,0])
X_train, Y_train = np.array(X_train), np.array(Y_train)

# Define the LSTM model
model = Sequential()
model.add(LSTM(units = 50, return_sequences=True, input_shape = (X_train.shape[1], 5)))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50))
model.add(Dense(units = 1))
model.summary()
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Train the LSTM model
model.fit(X_train, Y_train, epochs = 30, batch_size =50)

# Create input and output sequences for testing the model
past = ada_train.tail(60)
past_ada_df = past.append(ada_test, ignore_index=True)
testing_ada = past_ada_df[['Open', 'Close', 'High', 'Low', 'Volume']].copy()
testing_ada = scaler.transform(testing_ada)
X_test = []
Y_test = []
for i in range(60, len(testing_ada)):
  X_test.append(testing_ada[i-60:i])
  Y_test.append(testing_ada[i,0])
X_test, Y_test = np.array(X_test), np.array(Y_test)

# Make predictions using the LSTM model
Y_pred = model.predict(X_test)

# Rescale the predicted and actual prices
scale = 1/scaler.scale_[0]
Y_test = Y_test*scale
Y_pred = Y_pred*scale

# Plot the predicted and actual prices
plt.figure(figsize=(20,10))
plt.plot(Y_test, color = 'red', label = 'Actual Cardano Coin Price')
plt.plot(Y_pred, color = 'green', label = 'Predicted Cardano Coin Price')
plt.title('Cardano Price Prediction using RNN-LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# Calculate metrics
mse = np.mean((Y_pred - Y_test)**2)
mae = np.mean(np.abs(Y_pred - Y_test))
rmse = np.sqrt(mse)
r2 = 1 - np.sum((Y_test - Y_pred)**2) / np.sum((Y_test - np.mean(Y_test))**2)

# Print metrics
print("Mean Squared Error (MSE): ", mse)
print("Mean Absolute Error (MAE): ", mae)
print("Root Mean Squared Error (RMSE): ", rmse)
print("R-squared (R2): ", r2)

# Calculate correlation between predicted and actual prices
corr = np.corrcoef(Y_pred.reshape(-1), Y_test.reshape(-1))[0][1]

# Print correlation
print("Correlation: ", corr)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_50 (LSTM)              (None, 60, 50)            11200
#
#  dropout_40 (Dropout)        (None, 60, 50)            0
#
#  lstm_51 (LSTM)              (None, 60, 50)            20200
#
#  dropout_41 (Dropout)        (None, 60, 50)            0
#
#  lstm_52 (LSTM)              (None, 60, 50)            20200
#
#  dropout_42 (Dropout)        (None, 60, 50)            0
#
#  lstm_53 (LSTM)              (None, 60, 50)            20200
#
#  dropout_43 (Dropout)        (None, 60, 50)            0
#
#  lstm_54 (LSTM)              (None, 50)                20200
#
#  dense_10 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 92,051
# Trainable params: 92,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 16/16 [==============================] - 10s 144ms/step - loss: 0.0101
# Epoch 2/30
# 16/16 [==============================] - 2s 146ms/step - loss: 0.0045
# Epoch 3/30
# 16/16 [==============================] - 2s 145ms/step - loss: 0.0042
# Epoch 4/30
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0032
# Epoch 5/30
# 16/16 [==============================] - 2s 144ms/step - loss: 0.0030
# Epoch 6/30
# 16/16 [==============================] - 2s 147ms/step - loss: 0.0029
# Epoch 7/30
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0027
# Epoch 8/30
# 16/16 [==============================] - 2s 146ms/step - loss: 0.0034
# Epoch 9/30
# 16/16 [==============================] - 2s 146ms/step - loss: 0.0028
# Epoch 10/30
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0027
# Epoch 11/30
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0026
# Epoch 12/30
# 16/16 [==============================] - 2s 144ms/step - loss: 0.0025
# Epoch 13/30
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0026
# Epoch 14/30
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0024
# Epoch 15/30
# 16/16 [==============================] - 2s 147ms/step - loss: 0.0022
# Epoch 16/30
# 16/16 [==============================] - 2s 142ms/step - loss: 0.0024
# Epoch 17/30
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0020
# Epoch 18/30
# 16/16 [==============================] - 2s 146ms/step - loss: 0.0025
# Epoch 19/30
# 16/16 [==============================] - 2s 147ms/step - loss: 0.0019
# Epoch 20/30
# 16/16 [==============================] - 2s 150ms/step - loss: 0.0020
# Epoch 21/30
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0023
# Epoch 22/30
# 16/16 [==============================] - 2s 148ms/step - loss: 0.0030
# Epoch 23/30
# 16/16 [==============================] - 2s 149ms/step - loss: 0.0023
# Epoch 24/30
# 16/16 [==============================] - 2s 150ms/step - loss: 0.0020
# Epoch 25/30
# 16/16 [==============================] - 2s 151ms/step - loss: 0.0023
# Epoch 26/30
# 16/16 [==============================] - 2s 148ms/step - loss: 0.0025
# Epoch 27/30
# 16/16 [==============================] - 2s 144ms/step - loss: 0.0024
# Epoch 28/30
# 16/16 [==============================] - 2s 150ms/step - loss: 0.0021
# Epoch 29/30
# 16/16 [==============================] - 2s 152ms/step - loss: 0.0039
# Epoch 30/30
# 16/16 [==============================] - 2s 148ms/step - loss: 0.0029
# C:\Users\sahmed\AppData\Local\Temp\ipykernel_4644\3998791544.py:63: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   past_ada_df = past.append(ada_test, ignore_index=True)
# 18/18 [==============================] - 2s 37ms/step
# Mean Squared Error (MSE):  0.39793440201720554
# Mean Absolute Error (MAE):  0.4393233854954579
# Root Mean Squared Error (RMSE):  0.6308204197845894
# R-squared (R2):  -688.2279836605386
# Correlation:  0.8963613635005107

# %% [markdown]
# ### **LSTM model on DogeCoin price data**

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from tensorflow.keras.utils import plot_model

import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import seaborn as sns

# Load the dataset
data = pd.read_csv('coin_Dogecoin.csv')

# Filter for Binance Coin data only
doge = data[data['Name']=='Dogecoin'].copy()

# Split data into training and test sets
doge_train = doge[doge['Date']<'2020-01-01'].copy()
doge_test = doge[doge['Date']>='2020-01-01'].copy()

# Filter for Open, Close, High, Low, and Volume columns for the training 
training_doge = doge_train[['Open', 'Close', 'High', 'Low', 'Volume']].copy()

# Normalize the training set
scaler = MinMaxScaler()
training_doge = scaler.fit_transform(training_doge)

# Create input and output sequences for the LSTM model
X_train = []
Y_train = []
for i in range(60, len(training_doge)):
  X_train.append(training_doge[i-60:i])
  Y_train.append(training_doge[i,0])
X_train, Y_train = np.array(X_train), np.array(Y_train)

# Define the LSTM model
model = Sequential()
model.add(LSTM(units = 50, return_sequences=True, input_shape = (X_train.shape[1], 5)))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50))
model.add(Dense(units = 1))
model.summary()
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Train the LSTM model
model.fit(X_train, Y_train, epochs = 30, batch_size =50)

# Create input and output sequences for testing the model
past = doge_train.tail(60)
past_doge_df = past.append(doge_test, ignore_index=True)
testing_doge = past_doge_df[['Open', 'Close', 'High', 'Low', 'Volume']].copy()
testing_doge = scaler.transform(testing_doge)
X_test = []
Y_test = []
for i in range(60, len(testing_doge)):
  X_test.append(testing_doge[i-60:i])
  Y_test.append(testing_doge[i,0])
X_test, Y_test = np.array(X_test), np.array(Y_test)

# Make predictions using the LSTM model
Y_pred = model.predict(X_test)

# Rescale the predicted and actual prices
scale = 1/scaler.scale_[0]
Y_test = Y_test*scale
Y_pred = Y_pred*scale

# Plot the predicted and actual prices
plt.figure(figsize=(20,10))
plt.plot(Y_test, color = 'red', label = 'Actual doge Coin Price')
plt.plot(Y_pred, color = 'green', label = 'Predicted doge Coin Price')
plt.title('doge Price Prediction using RNN-LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# Calculate metrics
mse = np.mean((Y_pred - Y_test)**2)
mae = np.mean(np.abs(Y_pred - Y_test))
rmse = np.sqrt(mse)
r2 = 1 - np.sum((Y_test - Y_pred)**2) / np.sum((Y_test - np.mean(Y_test))**2)

# Print metrics
print("Mean Squared Error (MSE): ", mse)
print("Mean Absolute Error (MAE): ", mae)
print("Root Mean Squared Error (RMSE): ", rmse)
print("R-squared (R2): ", r2)

# Calculate correlation between predicted and actual prices
corr = np.corrcoef(Y_pred.reshape(-1), Y_test.reshape(-1))[0][1]

# Print correlation
print("Correlation: ", corr)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_55 (LSTM)              (None, 60, 50)            11200
#
#  dropout_44 (Dropout)        (None, 60, 50)            0
#
#  lstm_56 (LSTM)              (None, 60, 50)            20200
#
#  dropout_45 (Dropout)        (None, 60, 50)            0
#
#  lstm_57 (LSTM)              (None, 60, 50)            20200
#
#  dropout_46 (Dropout)        (None, 60, 50)            0
#
#  lstm_58 (LSTM)              (None, 60, 50)            20200
#
#  dropout_47 (Dropout)        (None, 60, 50)            0
#
#  lstm_59 (LSTM)              (None, 50)                20200
#
#  dense_11 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 92,051
# Trainable params: 92,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 13/13 [==============================] - 11s 145ms/step - loss: 0.0143
# Epoch 2/30
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0067
# Epoch 3/30
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0065
# Epoch 4/30
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0040
# Epoch 5/30
# 13/13 [==============================] - 2s 145ms/step - loss: 0.0030
# Epoch 6/30
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0029
# Epoch 7/30
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0022
# Epoch 8/30
# 13/13 [==============================] - 2s 144ms/step - loss: 0.0020
# Epoch 9/30
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0033
# Epoch 10/30
# 13/13 [==============================] - 2s 145ms/step - loss: 0.0022
# Epoch 11/30
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0020
# Epoch 12/30
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0017
# Epoch 13/30
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0022
# Epoch 14/30
# 13/13 [==============================] - 2s 145ms/step - loss: 0.0023
# Epoch 15/30
# 13/13 [==============================] - 2s 144ms/step - loss: 0.0019
# Epoch 16/30
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0015
# Epoch 17/30
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0018
# Epoch 18/30
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0014
# Epoch 19/30
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0015
# Epoch 20/30
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0015
# Epoch 21/30
# 13/13 [==============================] - 2s 133ms/step - loss: 0.0015
# Epoch 22/30
# 13/13 [==============================] - 2s 135ms/step - loss: 0.0015
# Epoch 23/30
# 13/13 [==============================] - 2s 135ms/step - loss: 0.0016
# Epoch 24/30
# 13/13 [==============================] - 2s 132ms/step - loss: 0.0014
# Epoch 25/30
# 13/13 [==============================] - 2s 135ms/step - loss: 0.0014
# Epoch 26/30
# 13/13 [==============================] - 2s 134ms/step - loss: 0.0013
# Epoch 27/30
# 13/13 [==============================] - 2s 135ms/step - loss: 0.0015
# Epoch 28/30
# 13/13 [==============================] - 2s 131ms/step - loss: 0.0013
# Epoch 29/30
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0014
# Epoch 30/30
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0016
# C:\Users\sahmed\AppData\Local\Temp\ipykernel_4644\1385144225.py:63: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   past_doge_df = past.append(doge_test, ignore_index=True)
# 31/31 [==============================] - 3s 39ms/step
# Mean Squared Error (MSE):  0.01108778162327433
# Mean Absolute Error (MAE):  0.03807923857753113
# Root Mean Squared Error (RMSE):  0.10529853571286892
# R-squared (R2):  -1074.7115817909676
# Correlation:  0.7820296249420753

# %% [markdown]
# ### **LSTM model on Ethereum Coin price data**

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from tensorflow.keras.utils import plot_model

import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import seaborn as sns

# Load the dataset
data = pd.read_csv('coin_Ethereum.csv')

# Filter for Binance Coin data only
eth = data[data['Name']=='Ethereum'].copy()

# Split data into training and test sets
eth_train = eth[eth['Date']<'2020-01-01'].copy()
eth_test = eth[eth['Date']>='2020-01-01'].copy()

# Filter for Open, Close, High, Low, and Volume columns for the training 
training_eth = eth_train[['Open', 'Close', 'High', 'Low', 'Volume']].copy()

# Normalize the training set
scaler = MinMaxScaler()
training_eth = scaler.fit_transform(training_eth)

# Create input and output sequences for the LSTM model
X_train = []
Y_train = []
for i in range(60, len(training_eth)):
  X_train.append(training_eth[i-60:i])
  Y_train.append(training_eth[i,0])
X_train, Y_train = np.array(X_train), np.array(Y_train)

# Define the LSTM model
model = Sequential()
model.add(LSTM(units = 50, return_sequences=True, input_shape = (X_train.shape[1], 5)))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50))
model.add(Dense(units = 1))
model.summary()
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Train the LSTM model
model.fit(X_train, Y_train, epochs = 30, batch_size =50)

# Create input and output sequences for testing the model
past = eth_train.tail(60)
past_eth_df = past.append(eth_test, ignore_index=True)
testing_eth = past_eth_df[['Open', 'Close', 'High', 'Low', 'Volume']].copy()
testing_eth = scaler.transform(testing_eth)
X_test = []
Y_test = []
for i in range(60, len(testing_eth)):
  X_test.append(testing_eth[i-60:i])
  Y_test.append(testing_eth[i,0])
X_test, Y_test = np.array(X_test), np.array(Y_test)

# Make predictions using the LSTM model
Y_pred = model.predict(X_test)

# Rescale the predicted and actual prices
scale = 1/scaler.scale_[0]
Y_test = Y_test*scale
Y_pred = Y_pred*scale

# Plot the predicted and actual prices
plt.figure(figsize=(20,10))
plt.plot(Y_test, color = 'red', label = 'Actual Ethereum Coin Price')
plt.plot(Y_pred, color = 'green', label = 'Predicted Ethereum Coin Price')
plt.title('Ethereum Price Prediction using RNN-LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# Calculate metrics
mse = np.mean((Y_pred - Y_test)**2)
mae = np.mean(np.abs(Y_pred - Y_test))
rmse = np.sqrt(mse)
r2 = 1 - np.sum((Y_test - Y_pred)**2) / np.sum((Y_test - np.mean(Y_test))**2)

# Print metrics
print("Mean Squared Error (MSE): ", mse)
print("Mean Absolute Error (MAE): ", mae)
print("Root Mean Squared Error (RMSE): ", rmse)
print("R-squared (R2): ", r2)

# Calculate correlation between predicted and actual prices
corr = np.corrcoef(Y_pred.reshape(-1), Y_test.reshape(-1))[0][1]

# Print correlation
print("Correlation: ", corr)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_60 (LSTM)              (None, 60, 50)            11200
#
#  dropout_48 (Dropout)        (None, 60, 50)            0
#
#  lstm_61 (LSTM)              (None, 60, 50)            20200
#
#  dropout_49 (Dropout)        (None, 60, 50)            0
#
#  lstm_62 (LSTM)              (None, 60, 50)            20200
#
#  dropout_50 (Dropout)        (None, 60, 50)            0
#
#  lstm_63 (LSTM)              (None, 60, 50)            20200
#
#  dropout_51 (Dropout)        (None, 60, 50)            0
#
#  lstm_64 (LSTM)              (None, 50)                20200
#
#  dense_12 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 92,051
# Trainable params: 92,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 13/13 [==============================] - 10s 143ms/step - loss: 0.0342
# Epoch 2/30
# 13/13 [==============================] - 2s 133ms/step - loss: 0.0116
# Epoch 3/30
# 13/13 [==============================] - 2s 134ms/step - loss: 0.0074
# Epoch 4/30
# 13/13 [==============================] - 2s 132ms/step - loss: 0.0061
# Epoch 5/30
# 13/13 [==============================] - 2s 132ms/step - loss: 0.0061
# Epoch 6/30
# 13/13 [==============================] - 2s 134ms/step - loss: 0.0060
# Epoch 7/30
# 13/13 [==============================] - 2s 127ms/step - loss: 0.0052
# Epoch 8/30
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0054
# Epoch 9/30
# 13/13 [==============================] - 2s 131ms/step - loss: 0.0051
# Epoch 10/30
# 13/13 [==============================] - 2s 128ms/step - loss: 0.0045
# Epoch 11/30
# 13/13 [==============================] - 2s 133ms/step - loss: 0.0052
# Epoch 12/30
# 13/13 [==============================] - 2s 128ms/step - loss: 0.0055
# Epoch 13/30
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0051
# Epoch 14/30
# 13/13 [==============================] - 2s 135ms/step - loss: 0.0063
# Epoch 15/30
# 13/13 [==============================] - 2s 128ms/step - loss: 0.0063
# Epoch 16/30
# 13/13 [==============================] - 2s 129ms/step - loss: 0.0049
# Epoch 17/30
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0041
# Epoch 18/30
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0038
# Epoch 19/30
# 13/13 [==============================] - 2s 133ms/step - loss: 0.0036
# Epoch 20/30
# 13/13 [==============================] - 2s 134ms/step - loss: 0.0032
# Epoch 21/30
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0032
# Epoch 22/30
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0034
# Epoch 23/30
# 13/13 [==============================] - 2s 128ms/step - loss: 0.0040
# Epoch 24/30
# 13/13 [==============================] - 2s 133ms/step - loss: 0.0033
# Epoch 25/30
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0039
# Epoch 26/30
# 13/13 [==============================] - 2s 131ms/step - loss: 0.0034
# Epoch 27/30
# 13/13 [==============================] - 2s 125ms/step - loss: 0.0029
# Epoch 28/30
# 13/13 [==============================] - 2s 128ms/step - loss: 0.0027
# Epoch 29/30
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0061
# Epoch 30/30
# 13/13 [==============================] - 2s 127ms/step - loss: 0.0050
# C:\Users\sahmed\AppData\Local\Temp\ipykernel_4644\3800499838.py:63: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   past_eth_df = past.append(eth_test, ignore_index=True)
# 31/31 [==============================] - 3s 36ms/step
# Mean Squared Error (MSE):  879796.1935757834
# Mean Absolute Error (MAE):  561.4523063147408
# Root Mean Squared Error (RMSE):  937.974516485274
# R-squared (R2):  -1538.7427648101657
# Correlation:  0.9232830136123126

# %% [markdown]
# ### **LSTM model on Litecoin Coin price data**

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from tensorflow.keras.utils import plot_model

import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import seaborn as sns

# Load the dataset
data = pd.read_csv('coin_Litecoin.csv')

# Filter for Binance Coin data only
ltc = data[data['Name']=='Litecoin'].copy()

# Split data into training and test sets
ltc_train = ltc[ltc['Date']<'2020-01-01'].copy()
ltc_test = ltc[ltc['Date']>='2020-01-01'].copy()

# Filter for Open, Close, High, Low, and Volume columns for the training 
training_ltc = ltc_train[['Open', 'Close', 'High', 'Low', 'Volume']].copy()

# Normalize the training set
scaler = MinMaxScaler()
training_ltc = scaler.fit_transform(training_ltc)

# Create input and output sequences for the LSTM model
X_train = []
Y_train = []
for i in range(60, len(training_ltc)):
  X_train.append(training_ltc[i-60:i])
  Y_train.append(training_ltc[i,0])
X_train, Y_train = np.array(X_train), np.array(Y_train)

# Define the LSTM model
model = Sequential()
model.add(LSTM(units = 50, return_sequences=True, input_shape = (X_train.shape[1], 5)))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units = 50))
model.add(Dense(units = 1))
model.summary()
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Train the LSTM model
model.fit(X_train, Y_train, epochs = 30, batch_size =50)

# Create input and output sequences for testing the model
past = ltc_train.tail(60)
past_ltc_df = past.append(ltc_test, ignore_index=True)
testing_ltc = past_ltc_df[['Open', 'Close', 'High', 'Low', 'Volume']].copy()
testing_ltc = scaler.transform(testing_ltc)
X_test = []
Y_test = []
for i in range(60, len(testing_ltc)):
  X_test.append(testing_ltc[i-60:i])
  Y_test.append(testing_ltc[i,0])
X_test, Y_test = np.array(X_test), np.array(Y_test)

# Make predictions using the LSTM model
Y_pred = model.predict(X_test)

# Rescale the predicted and actual prices
scale = 1/scaler.scale_[0]
Y_test = Y_test*scale
Y_pred = Y_pred*scale

# Plot the predicted and actual prices
plt.figure(figsize=(20,10))
plt.plot(Y_test, color = 'red', label = 'Actual LiteCoin Price')
plt.plot(Y_pred, color = 'green', label = 'Predicted LiteCoin Coin Price')
plt.title('LiteCoin Price Prediction using RNN-LSTM')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# Calculate metrics
mse = np.mean((Y_pred - Y_test)**2)
mae = np.mean(np.abs(Y_pred - Y_test))
rmse = np.sqrt(mse)
r2 = 1 - np.sum((Y_test - Y_pred)**2) / np.sum((Y_test - np.mean(Y_test))**2)

# Print metrics
print("Mean Squared Error (MSE): ", mse)
print("Mean Absolute Error (MAE): ", mae)
print("Root Mean Squared Error (RMSE): ", rmse)
print("R-squared (R2): ", r2)

# Calculate correlation between predicted and actual prices
corr = np.corrcoef(Y_pred.reshape(-1), Y_test.reshape(-1))[0][1]

# Print correlation
print("Correlation: ", corr)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_65 (LSTM)              (None, 60, 50)            11200
#
#  dropout_52 (Dropout)        (None, 60, 50)            0
#
#  lstm_66 (LSTM)              (None, 60, 50)            20200
#
#  dropout_53 (Dropout)        (None, 60, 50)            0
#
#  lstm_67 (LSTM)              (None, 60, 50)            20200
#
#  dropout_54 (Dropout)        (None, 60, 50)            0
#
#  lstm_68 (LSTM)              (None, 60, 50)            20200
#
#  dropout_55 (Dropout)        (None, 60, 50)            0
#
#  lstm_69 (LSTM)              (None, 50)                20200
#
#  dense_13 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 92,051
# Trainable params: 92,051
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 13/13 [==============================] - 10s 143ms/step - loss: 0.0377
# Epoch 2/30
# 13/13 [==============================] - 2s 148ms/step - loss: 0.0186
# Epoch 3/30
# 13/13 [==============================] - 2s 136ms/step - loss: 0.0150
# Epoch 4/30
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0133
# Epoch 5/30
# 13/13 [==============================] - 2s 136ms/step - loss: 0.0113
# Epoch 6/30
# 13/13 [==============================] - 2s 144ms/step - loss: 0.0095
# Epoch 7/30
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0096
# Epoch 8/30
# 13/13 [==============================] - 2s 133ms/step - loss: 0.0089
# Epoch 9/30
# 13/13 [==============================] - 2s 133ms/step - loss: 0.0079
# Epoch 10/30
# 13/13 [==============================] - 2s 129ms/step - loss: 0.0096
# Epoch 11/30
# 13/13 [==============================] - 2s 132ms/step - loss: 0.0105
# Epoch 12/30
# 13/13 [==============================] - 2s 132ms/step - loss: 0.0068
# Epoch 13/30
# 13/13 [==============================] - 2s 131ms/step - loss: 0.0057
# Epoch 14/30
# 13/13 [==============================] - 2s 124ms/step - loss: 0.0064
# Epoch 15/30
# 13/13 [==============================] - 2s 120ms/step - loss: 0.0056
# Epoch 16/30
# 13/13 [==============================] - 2s 119ms/step - loss: 0.0055
# Epoch 17/30
# 13/13 [==============================] - 2s 130ms/step - loss: 0.0044
# Epoch 18/30
# 13/13 [==============================] - 2s 145ms/step - loss: 0.0048
# Epoch 19/30
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0038
# Epoch 20/30
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0040
# Epoch 21/30
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0033
# Epoch 22/30
# 13/13 [==============================] - 2s 136ms/step - loss: 0.0035
# Epoch 23/30
# 13/13 [==============================] - 2s 140ms/step - loss: 0.0036
# Epoch 24/30
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0034
# Epoch 25/30
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0031
# Epoch 26/30
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0033
# Epoch 27/30
# 13/13 [==============================] - 2s 136ms/step - loss: 0.0040
# Epoch 28/30
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0035
# Epoch 29/30
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0034
# Epoch 30/30
# 13/13 [==============================] - 2s 137ms/step - loss: 0.0030
# C:\Users\sahmed\AppData\Local\Temp\ipykernel_4644\1381135452.py:63: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   past_ltc_df = past.append(ltc_test, ignore_index=True)
# 31/31 [==============================] - 3s 37ms/step
# Mean Squared Error (MSE):  8166.281208598592
# Mean Absolute Error (MAE):  66.59429930661133
# Root Mean Squared Error (RMSE):  90.36747871108605
# R-squared (R2):  -1912.9141887982958
# Correlation:  0.9345847253307571
